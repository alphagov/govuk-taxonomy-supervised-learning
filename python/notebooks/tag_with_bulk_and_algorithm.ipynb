# %%
import numpy as np
import pandas as pd
import os
import re
import yaml
# fuzz is used to compare TWO strings
from fuzzywuzzy import fuzz

# %%
DATADIR = os.getenv('DATADIR')
DATADIR
# Out:
# '/data/2018-03-27'

# %%
print("model v2.0.0 was run on data dated {}".format(DATADIR))
# Out:
# model v2.0.0 was run on data dated /data/2018-03-27

# %% [markdown]
# ## 1. Read in data

# %%
full_content = pd.read_csv(
    os.path.join(DATADIR, 'full_content.csv.gz'),
    dtype=object,
    compression='gzip', 
    usecols=['content_id']
)

# %%
labelled_level2 = pd.read_csv(
    os.path.join(DATADIR, 'labelled_level2.csv.gz'),
    dtype=object,
    compression='gzip', 
    usecols=['content_id']
)

# %%
unlabelled = pd.read_csv(
    os.path.join(DATADIR, 'unlabelled_predictions_meta.csv.gz'),
    dtype=object,
    compression='gzip'
)

# %%
unlabelled_unique_content = unlabelled.drop_duplicates('content_id').copy()

# %%
prim_pub_map = pd.read_csv(
    os.path.join(DATADIR, 'bulkmap_pub_org_to_taxon.csv'),
    dtype=object,
    skipfooter=1,
    engine='python'
)

# %%
taxons = pd.read_csv(
    os.path.join(DATADIR, 'clean_taxons.csv.gz'),
    dtype=object,
    compression='gzip'
)

# %%
taxon_names = taxons['taxon_name'].unique()

# %%
taxon_names.shape
# Out:
# (2471,)

# %% [markdown]
# ### Primary publishing org

# %%
# sort out the fuzzy matching for taxon name
prim_pub_map['taxon_name'] = ''

for taxon_name in taxon_names:
    for index, row in prim_pub_map.iterrows():
        if row['Bulk Tag to']:
            fuzzy = row['Bulk Tag to']
        
            score = fuzz.token_sort_ratio(fuzzy, taxon_name)
        
            if score > 90:
                
                row['taxon_name'] = taxon_name

# %%
taxon_name_id_dict = dict(zip((taxons['taxon_name']),
                        taxons['content_id']))

# %%
prim_pub_map['taxon_id'] = prim_pub_map['taxon_name'].map(taxon_name_id_dict).copy()

# %%
def strip_prim_org(x):
    if x=='':
        return ''
    else:
        return re.sub('\"|}',"",x.split("=>")[1])

# %%
prim_pub_map['primary_publishing_organisation'] = prim_pub_map['primary_publishing_organisation'].fillna('').copy()

# %%
prim_pub_map['primary_publishing_organisation'] = prim_pub_map['primary_publishing_organisation'].\
                map(strip_prim_org)

# %%
prim_pub_map.head()
# Out:
#                  primary_publishing_organisation  \
# 0
# 1                British Cattle Movement Service
# 2        Building Regulations Advisory Committee
# 3  Commonwealth Scholarship Commission in the UK
# 4                             Copyright Tribunal
#
#   COUNTA of primary_publishing_organisation          Bulk Tag to  \
# 0                                         0                  NaN
# 1                                         1                  NaN
# 2                                         1  Business regulation
# 3                                         1                  NaN
# 4                                         1           Copyright
#
#                              Level           taxon_name  \
# 0                              NaN
# 1                              NaN
# 2               Level 3 (Business)  Business regulation
# 3                              NaN
# 4  Level 3 (Crime Justice and Law)            Copyright
#
#                                taxon_id
# 0                                   NaN
# 1                                   NaN
# 2  33bc0eed-62c7-4b0b-9a93-626c9e10c025
# 3                                   NaN
# 4  7b2a45e2-2f20-4331-a2b6-de512b007a52

# %%
pub_taxon_dict = dict(zip((prim_pub_map['primary_publishing_organisation']),
                        prim_pub_map['taxon_name']))

# %%
unlabelled_unique_content['taxon2label_bulk'] = unlabelled_unique_content['primary_publishing_organisation'].map(pub_taxon_dict)

# %%
unlabelled_unique_content[unlabelled_unique_content['taxon2label_bulk'].isnull()].shape
# Out:
# (15161, 18)

# %%
unlabelled_unique_content[unlabelled_unique_content['taxon2label_bulk'].notnull()].shape
# Out:
# (70273, 18)

# %%
bulk_tags = unlabelled_unique_content[unlabelled_unique_content['taxon2label_bulk'].notnull()].copy()

# %%
bulk_tags['taxon2label'] = bulk_tags['taxon2label_bulk']

# %%
bulk_tags['prob'] = np.nan
bulk_tags['prob_cat'] = np.nan

# %%
bulk_tags['how_tagged'] = 'prim_org_bulk_tag'

# %%
bulk_tags.shape
# Out:
# (70273, 19)

# %% [markdown]
# ### document type

# %%
doctype_taxon_dict = {'business_finance_support_scheme':'ccfc50f5-e193-4dac-9d78-50b3a8bb24c5',
'countryside_stewardship_grant':'9129d716-365b-44ba-9856-383423fe1e41',
'drug_safety_update':'51bbdf23-292a-4b74-8a66-f7db6b93b163',
'esi_fund':'2894668d-0c21-491a-9069-a271e67f6025',
'international_development_fund':'9fb30a53-70fb-4f1c-878b-0064b202d1ba',
'medical_safety_alert':'51bbdf23-292a-4b74-8a66-f7db6b93b163',
'residential_property_tribunal_decision':'0c46aba4-1986-4574-b957-734c6d104546',
'residential_property_tribunal_decision':'357110bb-cbc5-4708-9711-1b26e6c63e86'}

# %%
unlabelled_unique_content2 = unlabelled.drop_duplicates('content_id').copy()

# %%
unlabelled_unique_content2['taxon_id_bulk'] = unlabelled_unique_content2['document_type'].map(doctype_taxon_dict)

# %%
name_taxon_id_dict = dict(zip((taxons['content_id']),
                        taxons['taxon_name']))

# %%
unlabelled_unique_content2[unlabelled_unique_content2['taxon_id_bulk'].notna()]
# Out:
#                                  content_id                    prob  \
# 10019  fdaa586a-62c8-4e94-90df-692a992308d9   6.721260203202688e-18
# 10020  89f79649-5099-4812-a401-0b2fa76927be   1.478241767199307e-16
# 10021  2fd4d095-25de-41e9-82fa-6d40d93e91d5  1.6279733355772076e-21
# 10022  4f798819-f2e0-468b-b73e-caa3aad4c8a1   4.050076611864226e-21
# 10023  2b295c16-6631-41e4-ad4e-9877c6e10086  1.4117464372578674e-19
# 10024  5685c19d-9c00-4e24-80e4-77ab226cff73  1.1927940297111594e-18
# 10025  5cd5eaf4-d636-44a0-8097-7c812fe6c58e   5.661420567708403e-19
# 10026  941fe7ac-9c1f-4dd3-b4bf-4be0fbf1eca0   4.799148058438732e-17
# 10027  f8ad9e86-f1f1-42e8-adfe-46ed5888b0eb  1.0482887690983224e-19
# 10028  e55de35c-e471-426e-882a-befb3b35f733   5.371464811687127e-19
# 10029  2c51846f-2e48-4ed9-a8ba-36ed0d33f563    9.09246028305026e-18
# 10030  d07b8237-12cb-444e-916c-9ec78b028496  2.5919009662634575e-17
# 10031  11019e56-1a44-462c-843d-504a6871de64   5.539207527335837e-18
# 10032  c9cecd7a-cae4-48dd-bdea-64e12da67334   2.088636600277168e-22
# 10029  /european-structural-investment-funds/informat...
# 10030  /european-structural-investment-funds/informat...
# 10031  /european-structural-investment-funds/sme-supp...
# 10032  /european-structural-investment-funds/low-carb...
# 10033  /european-structural-investment-funds/research...
# 10034  /european-structural-investment-funds/sme-supp...
# 10035  /european-structural-investment-funds/research...
# 10036  /european-structural-investment-funds/low-carb...
# 10037  /european-structural-investment-funds/sme-supp...
# 10038  /european-structural-investment-funds/informat...
# 10039  /european-structural-investment-funds/research...
# 10040  /european-structural-investment-funds/low-carb...
# 10041  /european-structural-investment-funds/informat...
# 10042  /european-structural-investment-funds/leeds-ci...
# 10043  /european-structural-investment-funds/research...
# 10044  /european-structural-investment-funds/research...
# 10045  /european-structural-investment-funds/sme-supp...
# 10046  /european-structural-investment-funds/sme-supp...
# 10047  /european-structural-investment-funds/research...
# 10048  /european-structural-investment-funds/sme-supp...
# ...                                                  ...
# 67202  /business-finance-support/business-start-up-gr...
# 67203     /business-finance-support/invest-in-manchester
# 67204  /business-finance-support/business-support-wes...
# 67205  /business-finance-support/the-south-east-midla...
# 67206  /business-finance-support/grants-for-business-...
# 67207  /business-finance-support/manufacturing-growth...
# 67208  /business-finance-support/coast-to-capital-exp...
# 67209  /business-finance-support/product-and-process-...
# 67210  /business-finance-support/new-business-start-u...
# 67211  /business-finance-support/innovate-northampton...
# 67212  /business-finance-support/instant-business-adv...
# 67213  /business-finance-support/fair-finance-busines...
# 67214  /business-finance-support/buckinghamshire-busi...
# 67215  /business-finance-support/built-environment-cl...
# 67216  /business-finance-support/funding-and-advice-f...
# 67217  /business-finance-support/sustainability-loan-...
# 67218  /business-finance-support/business-solutions-s...
# 67219  /business-finance-support/heritage-enterprise-...
# 67220  /business-finance-support/d2-business-starter-...
# 67221  /business-finance-support/innovate-uk-grant-fu...
# 67222  /business-finance-support/stafford-enterprise-...
# 67223  /business-finance-support/construction-industr...
# 67224  /business-finance-support/leader-programme-chi...
# 67225  /business-finance-support/national-skills-acad...
# 67226  /business-finance-support/employment-support-a...
# 67227  /business-finance-support/wenta-mentor-scheme-...
# 67228  /business-finance-support/marine-capital-fund-...
# 67229  /business-finance-support/city-business-librar...
# 67230  /business-finance-support/leader-programme-nor...
# 67231  /business-finance-support/flexible-support-pro...
#
#                                              description  \
# 10019  call to run project's enhancing the competitiv...
# 10020  call to run project's enhancing the competitiv...
# 10021  call for project’s providing research and inno...
# 10022  call to run a project to be delivered within t...
# 10023  call for project’s providing research and inno...
# 10024  call to run project's supporting the shift tow...
# 10025  call to run a project enhancing the competitiv...
# 10026  call to run a local or national technical assi...
# 10027  call to run a project to create and extend the...
# 10028  call to run project's enhancing the competitiv...
# 10029  call to run a project enhancing access to and ...
# 10030  call to run a project enhancing access to and ...
# 10031  call to run project's enhancing the competitiv...
# 10032  call to run project's supporting the shift tow...
# 10033  call for project’s providing research and inno...
# 10034  call to run project's enhancing the competitiv...
# 10035  call for project’s providing research and inno...
# 10036  call to run project's supporting the shift tow...
# 10037  call to run project's enhancing the competitiv...
# 10038  call to run a project enhancing access to and ...
# 10039  call for project’s providing research and inno...
# 10040  call to run project's supporting the shift tow...
# 10041  call for project’s enhancing access to and use...
# 10042  call to run a project to support the increase ...
# 10043  call for project’s providing research and inno...
# 10044  call for project’s providing research and inno...
# 10045  call to run a project enhancing the competitiv...
# 10046  call to run project's enhancing the competitiv...
# 10047  call for project’s providing research and inno...
# 10048  call to run a project supporting the competiti...
# ...                                                  ...
# 67202  grant to fund new businesses in the mansfield ...
# 67203  free support for businesses looking to expand ...
# 67204  planning marketing strategy investment and gen...
# 67205        12 hours of free business start-up support.
# 67206  grants for property development research staff...
# 67207  free advice and support for small and medium-s...
# 67208  loans for established small to medium-sized en...
# 67209  innovation funding for small businesses in yor...
# 67210  advice and support for entrepreneurs looking t...
# 67211  promoting research and innovation in small and...
# 67212  free business advice through live chat for bus...
# 67213  unsecured loans for small and medium-sized ent...
# 67214  grant funding to the value of £1 000 available...
# 67215  free support for small and medium-sized busine...
# 67216  funding technical and business expertise netwo...
# 67217  a loan fund to support businesses in the south...
# 67218  a range of business growth programmes to help ...
# 67219  funding to help restore neglected historic bui...
# 67220  free workshops and one-to-one support to help ...
# 67221  supports innovative uk businesses to realise t...
# 67222  free and confidential advice for new businesse...
# 67223  support and funding to help businesses increas...
# 67224  grant funding for rural businesses that want t...
# 67225  find quality assured training provision for yo...
# 67226  employment support for people who are eligible...
# 67227  up to 6 months' free business support from an ...
# 67228  support for marine businesses in cornwall look...
# 67229  free information seminars and workshops to hel...
# 67230  grants for rural businesses that want to grow ...
# 67231  advice on innovation for small and medium-size...
#
#                          document_type document_type_gp  \
# 10019                         esi_fund     org_entities
# 10020                         esi_fund     org_entities
# 10021                         esi_fund     org_entities
# 10022                         esi_fund     org_entities
# 10023                         esi_fund     org_entities
# 10024                         esi_fund     org_entities
# 10025                         esi_fund     org_entities
# 10026                         esi_fund     org_entities
# 10027                         esi_fund     org_entities
# 10028                         esi_fund     org_entities
# 10029                         esi_fund     org_entities
# 10030                         esi_fund     org_entities
# 10031                         esi_fund     org_entities
# 10032                         esi_fund     org_entities
# 10033                         esi_fund     org_entities
# 10034                         esi_fund     org_entities
# 10035                         esi_fund     org_entities
# 10036                         esi_fund     org_entities
# 10037                         esi_fund     org_entities
# 10038                         esi_fund     org_entities
# 10039                         esi_fund     org_entities
# 10040                         esi_fund     org_entities
# 10041                         esi_fund     org_entities
# 10042                         esi_fund     org_entities
# 10043                         esi_fund     org_entities
# 10044                         esi_fund     org_entities
# 10045                         esi_fund     org_entities
# 10046                         esi_fund     org_entities
# 10047                         esi_fund     org_entities
# 10048                         esi_fund     org_entities
# ...                                ...              ...
# 67202  business_finance_support_scheme     org_entities
# 67203  business_finance_support_scheme     org_entities
# 67204  business_finance_support_scheme     org_entities
# 67205  business_finance_support_scheme     org_entities
# 67206  business_finance_support_scheme     org_entities
# 67207  business_finance_support_scheme     org_entities
# 67208  business_finance_support_scheme     org_entities
# 67209  business_finance_support_scheme     org_entities
# 67210  business_finance_support_scheme     org_entities
# 67211  business_finance_support_scheme     org_entities
# 67212  business_finance_support_scheme     org_entities
# 67213  business_finance_support_scheme     org_entities
# 67214  business_finance_support_scheme     org_entities
# 67215  business_finance_support_scheme     org_entities
# 67216  business_finance_support_scheme     org_entities
# 67217  business_finance_support_scheme     org_entities
# 67218  business_finance_support_scheme     org_entities
# 67219  business_finance_support_scheme     org_entities
# 67220  business_finance_support_scheme     org_entities
# 67221  business_finance_support_scheme     org_entities
# 67222  business_finance_support_scheme     org_entities
# 67223  business_finance_support_scheme     org_entities
# 67224  business_finance_support_scheme     org_entities
# 67225  business_finance_support_scheme     org_entities
# 67226  business_finance_support_scheme     org_entities
# 67227  business_finance_support_scheme     org_entities
# 67228  business_finance_support_scheme     org_entities
# 67229  business_finance_support_scheme     org_entities
# 67230  business_finance_support_scheme     org_entities
# 67231  business_finance_support_scheme     org_entities
#
#             first_published_at level1taxon locale  \
# 10019  2018-03-02 09:35:15.000         NaN     en
# 10020  2018-03-02 09:41:11.000         NaN     en
# 10021  2018-03-02 10:23:39.000         NaN     en
# 10022  2018-03-26 15:20:18.000         NaN     en
# 10023  2018-03-02 10:16:27.000         NaN     en
# 10024  2018-03-02 08:42:09.000         NaN     en
# 10025  2018-03-02 10:18:00.000         NaN     en
# 10026  2018-03-02 09:15:22.000         NaN     en
# 10027  2018-03-02 09:13:07.000         NaN     en
# 10028  2018-03-02 09:45:44.000         NaN     en
# 10029  2018-03-02 09:23:40.000         NaN     en
# 10030  2018-03-02 09:19:25.000         NaN     en
# 10031  2018-03-02 09:55:18.000         NaN     en
# 10032  2018-03-02 09:42:14.000         NaN     en
# 10033  2018-03-02 10:26:31.000         NaN     en
# 10034  2018-03-02 10:09:18.000         NaN     en
# 10035  2018-03-02 10:34:41.000         NaN     en
# 10036  2018-03-02 09:33:30.000         NaN     en
# 10037  2018-03-02 10:04:06.000         NaN     en
# 10038  2018-03-02 09:22:22.000         NaN     en
# 10039  2018-03-02 10:18:50.000         NaN     en
# 10040  2018-03-02 09:37:03.000         NaN     en
# 10041  2018-03-02 09:26:37.000         NaN     en
# 10042  2018-03-26 15:16:01.000         NaN     en
# 10043  2018-03-02 10:31:31.000         NaN     en
# 10044  2018-03-02 10:48:37.000         NaN     en
# 10045  2018-03-02 10:19:31.000         NaN     en
# 10046  2018-03-02 09:59:50.000         NaN     en
# 10047  2018-03-02 10:09:01.000         NaN     en
# 10048  2018-03-02 09:11:38.000         NaN     en
# ...                        ...         ...    ...
# 67202  2017-03-20 10:26:41.000         NaN     en
# 67203  2017-03-20 10:28:12.000         NaN     en
# 67204  2017-03-20 10:27:00.000         NaN     en
# 67205  2017-10-16 11:14:36.000         NaN     en
# 67206  2017-03-20 10:26:50.000         NaN     en
# 67207  2017-03-20 10:26:19.000         NaN     en
# 67208  2017-03-20 10:27:18.000         NaN     en
# 67209  2017-03-20 10:27:12.000         NaN     en
# 67210  2017-03-20 10:27:37.000         NaN     en
# 67211  2017-05-31 12:43:15.000         NaN     en
# 67212  2017-03-20 10:27:59.000         NaN     en
# 67213  2017-03-20 10:27:57.000         NaN     en
# 67214  2017-09-06 13:43:51.000         NaN     en
# 67215  2017-04-10 08:49:17.000         NaN     en
# 67216  2017-03-20 10:27:57.000         NaN     en
# 67217  2017-03-20 10:26:28.000         NaN     en
# 67218  2017-03-20 10:26:18.000         NaN     en
# 67219  2017-03-20 10:27:58.000         NaN     en
# 67220  2017-05-31 13:52:12.000         NaN     en
# 67221  2017-12-13 13:46:41.000         NaN     en
# 67222  2017-03-20 10:27:08.000         NaN     en
# 67223  2017-03-20 10:26:32.000         NaN     en
# 67224  2017-08-15 12:16:42.000         NaN     en
# 67225  2017-03-20 10:27:12.000         NaN     en
# 67226  2017-03-20 10:27:04.000         NaN     en
# 67227  2017-03-20 10:26:55.000         NaN     en
# 67228  2017-03-20 10:28:02.000         NaN     en
# 67229  2017-03-20 10:27:19.000         NaN     en
# 67230  2017-08-11 12:56:53.000         NaN     en
# 67231  2017-03-20 10:28:07.000         NaN     en
#
#       primary_publishing_organisation        publishing_app taxon_id  \
# 10019                             NaN  specialist-publisher      NaN
# 10020                             NaN  specialist-publisher      NaN
# 10021                             NaN  specialist-publisher      NaN
# 10022                             NaN  specialist-publisher      NaN
# 10023                             NaN  specialist-publisher      NaN
# 10024                             NaN  specialist-publisher      NaN
# 10025                             NaN  specialist-publisher      NaN
# 10026                             NaN  specialist-publisher      NaN
# 10027                             NaN  specialist-publisher      NaN
# 10028                             NaN  specialist-publisher      NaN
# 10029                             NaN  specialist-publisher      NaN
# 10030                             NaN  specialist-publisher      NaN
# 10031                             NaN  specialist-publisher      NaN
# 10032                             NaN  specialist-publisher      NaN
# 10033                             NaN  specialist-publisher      NaN
# 10034                             NaN  specialist-publisher      NaN
# 10035                             NaN  specialist-publisher      NaN
# 10036                             NaN  specialist-publisher      NaN
# 10037                             NaN  specialist-publisher      NaN
# 10038                             NaN  specialist-publisher      NaN
# 10039                             NaN  specialist-publisher      NaN
# 10040                             NaN  specialist-publisher      NaN
# 10041                             NaN  specialist-publisher      NaN
# 10042                             NaN  specialist-publisher      NaN
# 10043                             NaN  specialist-publisher      NaN
# 10044                             NaN  specialist-publisher      NaN
# 10045                             NaN  specialist-publisher      NaN
# 10046                             NaN  specialist-publisher      NaN
# 10047                             NaN  specialist-publisher      NaN
# 10048                             NaN  specialist-publisher      NaN
# ...                               ...                   ...      ...
# 67202                             NaN  specialist-publisher      NaN
# 67203                             NaN  specialist-publisher      NaN
# 67204                             NaN  specialist-publisher      NaN
# 67205                             NaN  specialist-publisher      NaN
# 67206                             NaN  specialist-publisher      NaN
# 67207                             NaN  specialist-publisher      NaN
# 67208                             NaN  specialist-publisher      NaN
# 67209                             NaN  specialist-publisher      NaN
# 67210                             NaN  specialist-publisher      NaN
# 67211                             NaN  specialist-publisher      NaN
# 67212                             NaN  specialist-publisher      NaN
# 67213                             NaN  specialist-publisher      NaN
# 67214                             NaN  specialist-publisher      NaN
# 67215                             NaN  specialist-publisher      NaN
# 67216                             NaN  specialist-publisher      NaN
# 67217                             NaN  specialist-publisher      NaN
# 67218                             NaN  specialist-publisher      NaN
# 67219                             NaN  specialist-publisher      NaN
# 67220                             NaN  specialist-publisher      NaN
# 67221                             NaN  specialist-publisher      NaN
# 67222                             NaN  specialist-publisher      NaN
# 67223                             NaN  specialist-publisher      NaN
# 67224                             NaN  specialist-publisher      NaN
# 67225                             NaN  specialist-publisher      NaN
# 67226                             NaN  specialist-publisher      NaN
# 67227                             NaN  specialist-publisher      NaN
# 67228                             NaN  specialist-publisher      NaN
# 67229                             NaN  specialist-publisher      NaN
# 67230                             NaN  specialist-publisher      NaN
# 67231                             NaN  specialist-publisher      NaN
#
#                                                    title untagged_type  \
# 10019  sme support (business support): call in cumbri...      untagged
# 10020  sme support: call in stoke-on-trent and staffo...      untagged
# 10021  research and innovation: call in new anglia (o...      untagged
# 10022  leeds city region - neet programme (oc20s18p1047)      untagged
# 10023  research and innovation: call in the south eas...      untagged
# 10024  low carbon: call in stoke-on-trent and staffor...      untagged
# 10025  sme support - access to finance: call in north...      untagged
# 10026  technical assistance: call in england (oc00r18...      untagged
# 10027  sme support - manufacturing: call in england (...      untagged
# 10028  sme support (high growth smes): call in sheffi...      untagged
# 10029  information and communications technology: cal...      untagged
# 10030  information and communications technology: cal...      untagged
# 10031  sme support: call in the north east (oc25r18p ...      untagged
# 10032  low carbon: call in buckinghamshire thames val...      untagged
# 10033  research and innovation: call in the marches –...      untagged
# 10034  sme support: call in greater lincolnshire (oc1...      untagged
# 10035  research and innovation: call in hertfordshire...      untagged
# 10036  low carbon: call in enterprise m3 (oc10r18p 0738)      untagged
# 10037  sme support: call in leeds city region (oc20r1...      untagged
# 10038  information and communications technology: cal...      untagged
# 10039  research and innovation: call in sheffield cit...      untagged
# 10040  low carbon: call in cheshire and warrington (o...      untagged
# 10041  information and communications technology: cal...      untagged
# 10042  leeds city region - routeways: developing youn...      untagged
# 10043  research and innovation: call in enterprise m3...      untagged
# 10044  research and innovation: call in cheshire and ...      untagged
# 10045  sme support - manufacturing: call in north wes...      untagged
# 10046  sme support: call in liverpool city region (oc...      untagged
# 10047  research and innovation: call in buckinghamshi...      untagged
# 10048  sme support: international trade performance: ...      untagged
# ...                                                  ...           ...
# 67202         business start-up grant scheme - mansfield      untagged
# 67203                             invest in - manchester      untagged
# 67204                  business support - west berkshire      untagged
# 67205         the south east midlands start-up programme      untagged
# 67206  grants for business growth - stoke-on-trent an...      untagged
# 67207  manufacturing growth programme - midlands york...      untagged
# 67208  coast to capital expansion loan scheme - surre...      untagged
# 67209  product and process innovation - york north yo...      untagged
# 67210         new business start-up advice - east durham      untagged
# 67211                          innovate northamptonshire      untagged
# 67212         instant business advice - broxtowe borough      untagged
# 67213                                fair business loans      untagged
# 67214             buckinghamshire business growth grants      untagged
# 67215  built environment climate change innovations -...      untagged
# 67216         funding and advice for space services - uk      untagged
# 67217      sustainability loan fund - south east england      untagged
# 67218            business solutions - south west england      untagged
# 67219                      heritage enterprise (he) - uk      untagged
# 67220         d2 business starter programme - derbyshire      untagged
# 67221  innovate uk - grant funding innovation loans a...      untagged
# 67222  stafford enterprise business support - staffor...      untagged
# 67223  construction industry training board (citb) gr...      untagged
# 67224                       leader programme - chilterns      untagged
# 67225                national skills academies - england      untagged
# 67226       employment support and training (est) - bury      untagged
# 67227  wenta mentor scheme - bedfordshire buckinghams...      untagged
# 67228                     marine capital fund - cornwall      untagged
# 67229  city business library business information - l...      untagged
# 67230   leader programme – north & west northamptonshire      untagged
# 67231  flexible support programme innovation advice -...      untagged
#
#                     updated_at prob_cat                         taxon_id_bulk
# 10019  2018-03-26 15:57:52.046    <0.01  2894668d-0c21-491a-9069-a271e67f6025
# 
# %%
bulk_tags_doctype = unlabelled_unique_content2[unlabelled_unique_content2['taxon_label_bulk_doctype'].notnull()].copy()

# %%
bulk_tags_doctype['taxon2label'] = bulk_tags_doctype['taxon_label_bulk_doctype']

# %%
bulk_tags_doctype['prob'] = np.nan
bulk_tags_doctype['prob_cat'] = np.nan

# %%
bulk_tags_doctype['how_tagged'] = 'doctype_bulk_tag'

# %%
bulk_tags_doctype.shape
# Out:
# (356, 20)

# %% [markdown]
# ### Add to algorithm tags

# %%
unlabelled['prob'] = pd.to_numeric(unlabelled['prob'])
predictions = unlabelled[unlabelled['prob'] > 0.5]

# %%
no_uk_economy = predictions.loc[predictions['taxon2label'] != 'UK economy'].copy()

# %%
no_uk_economy_comms = no_uk_economy.loc[no_uk_economy['taxon2label'] != 'Media and communications'].copy()

# %%
no_uk_economy_comms['how_tagged'] = 'algorithm_v2.0.0'

# %%
no_uk_economy_comms.shape
# Out:
# (88503, 18)

# %%
no_uk_economy_comms.content_id.nunique()
# Out:
# 64323

# %%
no_uk_economy_comms.drop_duplicates(subset=['content_id', 'taxon2label']).content_id.nunique()
# Out:
# 64323

# %%
print("the algorithm tagged {}  out of {} ({}%) in-scope items".format(
no_uk_economy_comms.content_id.nunique(), 
unlabelled.content_id.nunique(),
(no_uk_economy_comms.content_id.nunique())/unlabelled.content_id.nunique() * 100
))
# Out:
# the algorithm tagged 64323  out of 85434 (75.28969731020437%) in-scope items

# %%
print("{} items would be tagged to level 2 or lower out of {} ({}%) in-scope items".format(
labelled_level2.content_id.nunique() + no_uk_economy_comms.content_id.nunique(), 
full_content.content_id.nunique(),
(labelled_level2.content_id.nunique() + no_uk_economy_comms.content_id.nunique())/full_content.content_id.nunique() * 100
))
# Out:
# 194531 items would be tagged to level 2 or lower out of 210154 (92.56592784339104%) in-scope items

# %%
print("There are {} items residul afer algorithm tag".format(
    unlabelled.content_id.nunique() - no_uk_economy_comms.content_id.nunique()))
# Out:
# There are 21111 items residul afer algorithm tag

# %% [markdown]
# ### concatenate bulk tags to algorithm tags
# These will go through rake task to remove superfluous ancesters

# %%
bulk_and_algorithm_tags = pd.concat([bulk_tags, bulk_tags_doctype, no_uk_economy_comms])

# %%
bulk_and_algorithm_tags.shape
# Out:
# (159132, 21)

# %%
bulk_and_algorithm_tags.groupby('how_tagged')['content_id'].nunique()
# Out:
# how_tagged
# algorithm_v2.0.0     64323
# doctype_bulk_tag       356
# prim_org_bulk_tag    70273
# Name: content_id, dtype: int64

# %%
bulk_and_algorithm_tags = bulk_and_algorithm_tags.drop_duplicates(subset=['content_id', 'taxon2label']).copy()

# %%
bulk_and_algorithm_tags.groupby('how_tagged')['content_id'].nunique()
# Out:
# how_tagged
# algorithm_v2.0.0     59558
# doctype_bulk_tag       356
# prim_org_bulk_tag    70273
# Name: content_id, dtype: int64

# %%
70273+356
# Out:
# 70629

# %%
print("the algorithm and the bulk tagging made the same predictions on {} items".format(
    no_uk_economy_comms.content_id.nunique()-bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='algorithm_v2.0.0'].content_id.nunique()))
# Out:
# the algorithm and the bulk tagging made the same predictions on 4765 items

# %%
bulk_and_algorithm_tags = bulk_and_algorithm_tags.rename(index=str, columns={"taxon2label": "taxon_tag"})

# %%
bulk_and_algorithm_tags.shape
# Out:
# (150474, 21)

# %% [markdown]
# ### get taxon id

# %%
bulk_and_algorithm_tags['taxon_id'] = bulk_and_algorithm_tags['taxon_tag'].map(taxon_name_id_dict)

# %% [markdown]
# ### remove World tags

# %%
bulk_and_algorithm_tags = bulk_and_algorithm_tags.loc[bulk_and_algorithm_tags['taxon_tag'] != 'world_level1'].copy()

# %%
bulk_and_algorithm_tags.shape
# Out:
# (150316, 21)

# %%
bulk_and_algorithm_tags = bulk_and_algorithm_tags[bulk_and_algorithm_tags['taxon_id'].notnull()].copy()

# %%
bulk_and_algorithm_tags[['content_id', 'taxon_tag', 'taxon_id']].shape
# Out:
# (119960, 3)

# %%
bulk_and_algorithm_tags[['content_id', 'taxon_tag', 'taxon_id', 'how_tagged']].head()
# Out:
#                                 content_id                          taxon_tag  \
# 5972  a113dedd-4320-4186-b1af-888437c6aedb                        Environment
# 5973  5d8d7f5f-7631-11e4-a3cb-005056011aef  International aid and development
# 5974  5e2e074d-7631-11e4-a3cb-005056011aef             Health and social care
# 5976  5f50cd4e-7631-11e4-a3cb-005056011aef                           Maritime
# 5977  b60d9e65-dc51-4a5b-8fbc-b6b15652b6ba                              World
#
#                                   taxon_id         how_tagged
# 5972  71d37f3a-7c8c-4128-8763-2fd5b831b9b9  prim_org_bulk_tag
# 5973  9fb30a53-70fb-4f1c-878b-0064b202d1ba  prim_org_bulk_tag
# 5974  8124ead8-8ebc-4faf-88ad-dd5cbcc92ba8  prim_org_bulk_tag
# 5976  4a9ab4d7-0d03-4c61-9e16-47787cbf53cd  prim_org_bulk_tag
# 5977  91b8ef20-74e7-4552-880c-50e6d73c2ff9  prim_org_bulk_tag

# %%
bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='algorithm_v2.0.0'].head()
# Out:
#                                                base_path  \
# 13121  /government/news/transformation-of-birmingham-...
# 16867  /government/news/hm-courts-tribunals-service-l...
# 27701  /government/news/civilcrime-news-more-dates-fo...
# 47881  /government/publications/appeal-a-judicial-rev...
# 48071  /government/publications/appeal-an-administrat...
#
#                                  content_id  \
# 13121  51f13e1a-ca7c-4b5d-9b0c-123a6e0d9480
# 16867  ad7af755-4ae4-4644-a957-a949bf1cccec
# 27701  2d6cf199-8bac-4dca-9446-b97f7b5d05e9
# 47881  04ff3b09-ce00-48a0-aa05-7c99e03ddfdc
# 48071  cd6e19e9-f652-49be-b665-43aaeab48cb7
#
#                                              description  document_type  \
# 13121  after an investment of £8.12m by hmcts birming...  press_release
# 16867  hmcts will today (18 january 2018) launch a te...  press_release
# 27701  new dates announced in hm courts and tribunals...     news_story
# 47881  use this index when submitting a 'core bundle'...           form
# 48071  use this index when submitting a 'core bundle'...           form
#
#              document_type_gp       first_published_at        how_tagged  \
# 13121  news_and_announcements  2018-03-01 11:00:18.000  algorithm_v2.0.0
# 16867  news_and_announcements  2018-01-19 10:47:26.000  algorithm_v2.0.0
# 27701  news_and_announcements  2018-01-10 15:43:00.000  algorithm_v2.0.0
# 47881                 service  2016-08-31 23:00:00.000  algorithm_v2.0.0
# 48071                 service  2016-08-31 23:00:00.000  algorithm_v2.0.0
#
#       level1taxon locale primary_publishing_organisation  \
# 13121         NaN     en   HM Courts & Tribunals Service
# 16867         NaN     en   HM Courts & Tribunals Service
# 27701         NaN     en                Legal Aid Agency
# 47881         NaN     en   HM Courts & Tribunals Service
# 48071         NaN     en   HM Courts & Tribunals Service
#
#                 ...             prob_cat publishing_app  \
# 13121           ...                >=0.8      whitehall
# 16867           ...             0.5-0.59      whitehall
# 27701           ...             0.7-0.79      whitehall
# 47881           ...                >=0.8      whitehall
# 48071           ...             0.6-0.69      whitehall
#
#                            taxon_tag taxon2label_bulk  \
# 13121  Administrative justice reform              NaN
# 16867  Administrative justice reform              NaN
# 27701  Administrative justice reform              NaN
# 47881  Administrative justice reform              NaN
# 48071  Administrative justice reform              NaN
#
#                                    taxon_id taxon_id_bulk  \
# 13121  66f7bd95-7e8b-4f33-ad7f-77a13ae92d49           NaN
# 16867  66f7bd95-7e8b-4f33-ad7f-77a13ae92d49           NaN
# 27701  66f7bd95-7e8b-4f33-ad7f-77a13ae92d49           NaN
# 47881  66f7bd95-7e8b-4f33-ad7f-77a13ae92d49           NaN
# 48071  66f7bd95-7e8b-4f33-ad7f-77a13ae92d49           NaN
#
#       taxon_label_bulk_doctype  \
# 13121                      NaN
# 16867                      NaN
# 27701                      NaN
# 47881                      NaN
# 48071                      NaN
#
#                                                    title untagged_type  \
# 13121  transformation of birmingham civil justice cen...      untagged
# 16867  hm courts & tribunals service launches project...      untagged
# 27701   civil/crime news: more dates for hmcts roadshows      untagged
# 47881  appeal a judicial review from the administrati...      untagged
# 48071  appeal an administrative judicial review or fr...      untagged
#
#                     updated_at
# 13121  2018-03-12 16:04:23.928
# 16867  2018-03-12 16:09:18.338
# 27701  2018-01-16 13:33:44.968
# 47881  2018-03-21 15:11:25.946
# 48071  2018-03-21 15:11:46.329
#
# [5 rows x 21 columns]

# %%
bulk_and_algorithm_tags.groupby(['how_tagged']).size()
# Out:
# how_tagged
# algorithm_v2.0.0     79687
# doctype_bulk_tag       356
# prim_org_bulk_tag    39917
# dtype: int64

# %%
bulk_and_algorithm_tags[['content_id', 'taxon_tag', 'taxon_id', 'how_tagged']].to_csv(os.path.join(DATADIR, 'bulk_and_algorithm_tags.csv.gz'),compression='gzip',index=False)

# %% [markdown]
# ### how much content is tagged now?

# %%
print("{} out of {} ({}%) unlabelled content items were tagged either by bulk or by algorithm".format(
    bulk_and_algorithm_tags.content_id.nunique(),
    unlabelled.content_id.nunique(),
    bulk_and_algorithm_tags.content_id.nunique()/unlabelled.content_id.nunique()*100))
# Out:
# 70585 out of 85434 (82.61933188192054%) unlabelled content items were tagged either by bulk or by algorithm

# %%
print("There would be a residual {} items that are hard-to-tag".format(
    unlabelled.content_id.nunique() - bulk_and_algorithm_tags.content_id.nunique()))
# Out:
# There would be a residual 14849 items that are hard-to-tag

# %%
bulk_and_algorithm_tags.groupby('how_tagged')['content_id'].nunique()
# Out:
# how_tagged
# algorithm_v2.0.0     59498
# doctype_bulk_tag       356
# prim_org_bulk_tag    39917
# Name: content_id, dtype: int64

# %%
39917+356
# Out:
# 40273

# %%
print("the total number of items tagged to level 2 or lower would be {}".format(
labelled_level2.content_id.nunique() + bulk_and_algorithm_tags.content_id.nunique() ))
# Out:
# the total number of items tagged to level 2 or lower would be 200793

# %%
print("{} items would be tagged to level 2 or lower out of {} ({}%) in-scope items".format(
labelled_level2.content_id.nunique() + bulk_and_algorithm_tags.content_id.nunique(), 
full_content.content_id.nunique(),
(labelled_level2.content_id.nunique() + bulk_and_algorithm_tags.content_id.nunique())/full_content.content_id.nunique() * 100
))
# Out:
# 200793 items would be tagged to level 2 or lower out of 210154 (95.54564747756407%) in-scope items

# %%
print("the ML would have tagged {}  out of {} ({}%) in-scope items".format(
bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='algorithm_v2.0.0'].content_id.nunique(), 
full_content.content_id.nunique(),
bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='algorithm_v2.0.0'].content_id.nunique()/full_content.content_id.nunique() * 100
))
# Out:
# the ML would have tagged 59498  out of 210154 (28.31161909837548%) in-scope items

# %%
print("the bulk tagging would have tagged {}  out of {} ({}%) in-scope items".format(
bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='prim_org_bulk_tag'].content_id.nunique() + bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='doctype_bulk_tag'].content_id.nunique(), 
full_content.content_id.nunique(),
(bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='prim_org_bulk_tag'].content_id.nunique() + bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='doctype_bulk_tag'].content_id.nunique())/full_content.content_id.nunique() * 100
))
# Out:
# the bulk tagging would have tagged 40273  out of 210154 (19.16356576605727%) in-scope items

# %%
print("the bulk tagging would have tagged {}  out of {} ({}%) in-scope items".format(
bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='prim_org_bulk_tag'].content_id.nunique() + bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='doctype_bulk_tag'].content_id.nunique(), 
unlabelled.content_id.nunique(),
(bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='prim_org_bulk_tag'].content_id.nunique() + bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='doctype_bulk_tag'].content_id.nunique())/unlabelled.content_id.nunique() * 100
))
# Out:
# the bulk tagging would have tagged 40273  out of 85434 (47.139312217618276%) in-scope items

# %%
both_methods = no_uk_economy_comms.content_id.nunique()-bulk_and_algorithm_tags[bulk_and_algorithm_tags['how_tagged']=='algorithm_v2.0.0'].content_id.nunique()

# %%
print("the algorithm and the bulk tagging made the same predictions on {} items".format(both_methods))
# Out:
# the algorithm and the bulk tagging made the same predictions on 4825 items

# %%
print("the ML would have tagged {}  out of {} ({}%) in-scope items".format(
# 29969567  /government/speeches/michael-gove-article-in-t...
#
#                                                 description     document_type  \
# 26590032  british embassy launches project support for t...  world_news_story
# 26590033  british embassy launches project support for t...  world_news_story
# 26590034  british embassy launches project support for t...  world_news_story
# 26590035  british embassy launches project support for t...  world_news_story
# 26590036  british embassy launches project support for t...  world_news_story
# 26590037  british embassy launches project support for t...  world_news_story
# 26590038  british embassy launches project support for t...  world_news_story
# 26590039  british embassy launches project support for t...  world_news_story
# 26590040  british embassy launches project support for t...  world_news_story
# 26590041  british embassy launches project support for t...  world_news_story
# 26590042  british embassy launches project support for t...  world_news_story
# 26590043  british embassy launches project support for t...  world_news_story
# 26590044  british embassy launches project support for t...  world_news_story
# 26590045  british embassy launches project support for t...  world_news_story
# 26590046  british embassy launches project support for t...  world_news_story
# 26590047  british embassy launches project support for t...  world_news_story
# 26590048  british embassy launches project support for t...  world_news_story
# 26590049  british embassy launches project support for t...  world_news_story
# 26590050  british embassy launches project support for t...  world_news_story
# 26590051  british embassy launches project support for t...  world_news_story
# 26590052  british embassy launches project support for t...  world_news_story
# 26590053  british embassy launches project support for t...  world_news_story
# 26590054  british embassy launches project support for t...  world_news_story
# 26590055  british embassy launches project support for t...  world_news_story
# 26590056  british embassy launches project support for t...  world_news_story
# 26590057  british embassy launches project support for t...  world_news_story
# 26590058  british embassy launches project support for t...  world_news_story
# 26590059  british embassy launches project support for t...  world_news_story
# 26590060  british embassy launches project support for t...  world_news_story
# 26590061  british embassy launches project support for t...  world_news_story
# ...                                                     ...               ...
# 29969538  education secretary michael gove reflects on t...  authored_article
# 29969539  education secretary michael gove reflects on t...  authored_article
# 29969540  education secretary michael gove reflects on t...  authored_article
# 29969541  education secretary michael gove reflects on t...  authored_article
# 29969542  education secretary michael gove reflects on t...  authored_article
# 29969543  education secretary michael gove reflects on t...  authored_article
# 29969544  education secretary michael gove reflects on t...  authored_article
# 29969545  education secretary michael gove reflects on t...  authored_article
# 29969546  education secretary michael gove reflects on t...  authored_article
# 29969547  education secretary michael gove reflects on t...  authored_article
# 29969548  education secretary michael gove reflects on t...  authored_article
# 29969549  education secretary michael gove reflects on t...  authored_article
# 29969550  education secretary michael gove reflects on t...  authored_article
# 29969551  education secretary michael gove reflects on t...  authored_article
# 29969552  education secretary michael gove reflects on t...  authored_article
# 29969553  education secretary michael gove reflects on t...  authored_article
# 29969554  education secretary michael gove reflects on t...  authored_article
# 29969555  education secretary michael gove reflects on t...  authored_article
# 29969556  education secretary michael gove reflects on t...  authored_article
# 29969557  education secretary michael gove reflects on t...  authored_article
# 29969558  education secretary michael gove reflects on t...  authored_article
# 29969559  education secretary michael gove reflects on t...  authored_article
# 29969560  education secretary michael gove reflects on t...  authored_article
# 29969561  education secretary michael gove reflects on t...  authored_article
# 29969562  education secretary michael gove reflects on t...  authored_article
# 29969563  education secretary michael gove reflects on t...  authored_article
# 29969564  education secretary michael gove reflects on t...  authored_article
# 29969565  education secretary michael gove reflects on t...  authored_article
# 29969566  education secretary michael gove reflects on t...  authored_article
# 29969567  education secretary michael gove reflects on t...  authored_article
# 29969561  news_and_announcements  2011-05-13 00:00:00.000
# 29969562  news_and_announcements  2011-05-13 00:00:00.000
# 29969563  news_and_announcements  2011-05-13 00:00:00.000
# 29969564  news_and_announcements  2011-05-13 00:00:00.000
# 29969565  news_and_announcements  2011-05-13 00:00:00.000
# 29969566  news_and_announcements  2011-05-13 00:00:00.000
# 29969567  news_and_announcements  2011-05-13 00:00:00.000
#
#                              level1taxon locale  \
# 26590032                             NaN     en
# 26590033                             NaN     en
# 26590034                             NaN     en
# 26590035                             NaN     en
# 26590036                             NaN     en
# 26590037                             NaN     en
# 26590038                             NaN     en
# 26590039                             NaN     en
# 26590040                             NaN     en
# 26590041                             NaN     en
# 26590042                             NaN     en
# 26590043                             NaN     en
# 26590044                             NaN     en
# 26590045                             NaN     en
# 26590046                             NaN     en
# 26590047                             NaN     en
# 26590048                             NaN     en
# 26590049                             NaN     en
# 26590050                             NaN     en
# 26590051                             NaN     en
# 26590052                             NaN     en
# 26590053                             NaN     en
# 26590054                             NaN     en
# 26590055                             NaN     en
# 26590056                             NaN     en
# 26590057                             NaN     en
# 26590058                             NaN     en
# 26590059                             NaN     en
# 26590060                             NaN     en
# 26590061                             NaN     en
# ...                                  ...    ...
# 29969538  Education, training and skills     en
# 29969539  Education, training and skills     en
# 29969540  Education, training and skills     en
# 29969541  Education, training and skills     en
# 29969542  Education, training and skills     en
# 29969543  Education, training and skills     en
# 29969544  Education, training and skills     en
# 29969545  Education, training and skills     en
# 29969546  Education, training and skills     en
# 29969547  Education, training and skills     en
# 29969548  Education, training and skills     en
# 29969549  Education, training and skills     en
# 29969550  Education, training and skills     en
# 29969551  Education, training and skills     en
# 29969552  Education, training and skills     en
# 29969553  Education, training and skills     en
# 29969554  Education, training and skills     en
# 29969555  Education, training and skills     en
# 29969556  Education, training and skills     en
# 29969557  Education, training and skills     en
# 29969558  Education, training and skills     en
# 29969559  Education, training and skills     en
# 29969560  Education, training and skills     en
# 29969561  Education, training and skills     en
# 29969562  Education, training and skills     en
# 29969563  Education, training and skills     en
# 29969564  Education, training and skills     en
# 29969565  Education, training and skills     en
# 29969566  Education, training and skills     en
# 29969567  Education, training and skills     en
#
#          primary_publishing_organisation publishing_app  \
# 26590032                             NaN      whitehall
# 26590033                             NaN      whitehall
# 26590034                             NaN      whitehall
# 26590035                             NaN      whitehall
# 26590036                             NaN      whitehall
# 26590037                             NaN      whitehall
# 26590038                             NaN      whitehall
# 26590039                             NaN      whitehall
# 26590040                             NaN      whitehall
# 26590041                             NaN      whitehall
# 26590042                             NaN      whitehall
# 26590043                             NaN      whitehall
# 26590044                             NaN      whitehall
# 26590045                             NaN      whitehall
# 26590046                             NaN      whitehall
# 26590047                             NaN      whitehall
# 26590048                             NaN      whitehall
# 26590049                             NaN      whitehall
# 26590050                             NaN      whitehall
# 26590051                             NaN      whitehall
# 26590052                             NaN      whitehall
# 26590053                             NaN      whitehall
# 26590054                             NaN      whitehall
# 26590055                             NaN      whitehall
# 26590056                             NaN      whitehall
# 26590057                             NaN      whitehall
# 26590058                             NaN      whitehall
# 26590059                             NaN      whitehall
# 26590060                             NaN      whitehall
# 26590061                             NaN      whitehall
# ...                                  ...            ...
# 29969538        Department for Education      whitehall
# 29969539        Department for Education      whitehall
# 29969540        Department for Education      whitehall
# 29969541        Department for Education      whitehall
# 29969542        Department for Education      whitehall
# 29969543        Department for Education      whitehall
# 29969544        Department for Education      whitehall
# 29969545        Department for Education      whitehall
# 29969546        Department for Education      whitehall
# 29969547        Department for Education      whitehall
# 29969548        Department for Education      whitehall
# 29969549        Department for Education      whitehall
# 29969550        Department for Education      whitehall
# 29969551        Department for Education      whitehall
# 29969552        Department for Education      whitehall
# 29969553        Department for Education      whitehall
# 29969554        Department for Education      whitehall
# 29969555        Department for Education      whitehall
# 29969556        Department for Education      whitehall
# 29969557        Department for Education      whitehall
# 29969558        Department for Education      whitehall
# 29969559        Department for Education      whitehall
# 29969560        Department for Education      whitehall
# 29969561        Department for Education      whitehall
# 29969562        Department for Education      whitehall
# 29969563        Department for Education      whitehall
# 29969564        Department for Education      whitehall
# 29969565        Department for Education      whitehall
# 29969566        Department for Education      whitehall
# 29969567        Department for Education      whitehall
#
#                                       taxon_id  \
# 26590032                                   NaN
# 26590033                                   NaN
# 26590034                                   NaN
# 26590035                                   NaN
# 26590036                                   NaN
# 26590037                                   NaN
# 26590038                                   NaN
# 26590039                                   NaN
# 26590040                                   NaN
# 26590041                                   NaN
# 26590042                                   NaN
# 26590043                                   NaN
# 26590044                                   NaN
# 26590045                                   NaN
# 26590046                                   NaN
# 26590047                                   NaN
# 26590048                                   NaN
# 26590049                                   NaN
# 26590050                                   NaN
# 26590051                                   NaN
# 26590052                                   NaN
# 26590053                                   NaN
# 26590054                                   NaN
# 26590055                                   NaN
# 26590056                                   NaN
# 26590057                                   NaN
# 26590058                                   NaN
# 26590059                                   NaN
# 26590060                                   NaN
# 26590061                                   NaN
# ...                                        ...
# 29969538  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969539  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969540  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969541  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969542  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969543  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969544  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969545  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969546  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969547  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969548  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969549  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969550  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969551  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969552  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969553  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969554  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969555  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969556  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969557  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969558  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969559  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969560  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969561  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969562  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969563  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969564  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969565  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969566  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
# 29969567  c58fdadd-7743-46d6-9629-90bb3ccc4ef0
#
#                                                       title untagged_type  \
# 26590032  capacity building for the macedonian security ...      untagged
# 26590033  capacity building for the macedonian security ...      untagged
# 26590034  capacity building for the macedonian security ...      untagged
# 26590035  capacity building for the macedonian security ...      untagged
# 26590036  capacity building for the macedonian security ...      untagged
# 26590037  capacity building for the macedonian security ...      untagged
# 26590038  capacity building for the macedonian security ...      untagged
# 26590039  capacity building for the macedonian security ...      untagged
# 26590040  capacity building for the macedonian security ...      untagged
# 26590041  capacity building for the macedonian security ...      untagged
# 26590042  capacity building for the macedonian security ...      untagged
# 26590043  capacity building for the macedonian security ...      untagged
# 26590044  capacity building for the macedonian security ...      untagged
# 26590045  capacity building for the macedonian security ...      untagged
# 26590046  capacity building for the macedonian security ...      untagged
# 26590047  capacity building for the macedonian security ...      untagged
# 26590048  capacity building for the macedonian security ...      untagged
# 26590049  capacity building for the macedonian security ...      untagged
# 26590050  capacity building for the macedonian security ...      untagged
# 26590051  capacity building for the macedonian security ...      untagged
# 26590052  capacity building for the macedonian security ...      untagged
# 26590053  capacity building for the macedonian security ...      untagged
# 26590054  capacity building for the macedonian security ...      untagged
# 26590055  capacity building for the macedonian security ...      untagged
# 26590056  capacity building for the macedonian security ...      untagged
# 26590057  capacity building for the macedonian security ...      untagged
# 26590058  capacity building for the macedonian security ...      untagged
# 26590059  capacity building for the macedonian security ...      untagged
# 26590060  capacity building for the macedonian security ...      untagged
# 26590061  capacity building for the macedonian security ...      untagged
# ...                                                     ...           ...
# 29969538  michael gove article in 'times education suppl...    level1only
# 29969539  michael gove article in 'times education suppl...    level1only
# 29969540  michael gove article in 'times education suppl...    level1only
# 29969541  michael gove article in 'times education suppl...    level1only
# 29969542  michael gove article in 'times education suppl...    level1only
# 29969543  michael gove article in 'times education suppl...    level1only
# 29969544  michael gove article in 'times education suppl...    level1only
# 29969545  michael gove article in 'times education suppl...    level1only
# 29969546  michael gove article in 'times education suppl...    level1only
# 29969547  michael gove article in 'times education suppl...    level1only
# 29969548  michael gove article in 'times education suppl...    level1only
# 29969549  michael gove article in 'times education suppl...    level1only
# 29969550  michael gove article in 'times education suppl...    level1only
# 29969551  michael gove article in 'times education suppl...    level1only
# 29969552  michael gove article in 'times education suppl...    level1only
# 29969553  michael gove article in 'times education suppl...    level1only
# 29969554  michael gove article in 'times education suppl...    level1only
# 29969555  michael gove article in 'times education suppl...    level1only
# 29969556  michael gove article in 'times education suppl...    level1only
# 29969557  michael gove article in 'times education suppl...    level1only
# 29969558  michael gove article in 'times education suppl...    level1only
# 29969559  michael gove article in 'times education suppl...    level1only
# 29969560  michael gove article in 'times education suppl...    level1only
# 29969561  michael gove article in 'times education suppl...    level1only
# 29969562  michael gove article in 'times education suppl...    level1only
# 29969563  michael gove article in 'times education suppl...    level1only
# 29969564  michael gove article in 'times education suppl...    level1only
# 29969565  michael gove article in 'times education suppl...    level1only
# 29969566  michael gove article in 'times education suppl...    level1only
# 29969567  michael gove article in 'times education suppl...    level1only
#
#                        updated_at   prob_cat      _merge
# 26590032  2017-08-24 16:27:39.284      <0.01  right_only
# 26590033  2017-08-24 16:27:39.284      <0.01  right_only
# 26590034  2017-08-24 16:27:39.284      <0.01  right_only
# 26590035  2017-08-24 16:27:39.284      <0.01  right_only
# 26590036  2017-08-24 16:27:39.284      <0.01  right_only
# 26590037  2017-08-24 16:27:39.284      <0.01  right_only
# 26590038  2017-08-24 16:27:39.284      <0.01  right_only
# 26590039  2017-08-24 16:27:39.284  0.01-0.09  right_only
# 26590040  2017-08-24 16:27:39.284      <0.01  right_only
# 26590041  2017-08-24 16:27:39.284      <0.01  right_only
# 26590042  2017-08-24 16:27:39.284      <0.01  right_only
# 26590043  2017-08-24 16:27:39.284      <0.01  right_only
# 26590044  2017-08-24 16:27:39.284      <0.01  right_only
# 26590045  2017-08-24 16:27:39.284      <0.01  right_only
# 26590046  2017-08-24 16:27:39.284      <0.01  right_only
# 26590047  2017-08-24 16:27:39.284      <0.01  right_only
# 26590048  2017-08-24 16:27:39.284      <0.01  right_only
# 26590049  2017-08-24 16:27:39.284      <0.01  right_only
# 26590050  2017-08-24 16:27:39.284  0.01-0.09  right_only
# 26590051  2017-08-24 16:27:39.284  0.01-0.09  right_only
# 26590052  2017-08-24 16:27:39.284      <0.01  right_only
# 26590053  2017-08-24 16:27:39.284      <0.01  right_only
# 26590054  2017-08-24 16:27:39.284      <0.01  right_only
# 26590055  2017-08-24 16:27:39.284      <0.01  right_only
# 26590056  2017-08-24 16:27:39.284      <0.01  right_only
# 26590057  2017-08-24 16:27:39.284      <0.01  right_only
# 26590058  2017-08-24 16:27:39.284      <0.01  right_only
# 26590059  2017-08-24 16:27:39.284      <0.01  right_only
# 26590060  2017-08-24 16:27:39.284      <0.01  right_only
# 26590061  2017-08-24 16:27:39.284      <0.01  right_only
# ...                           ...        ...         ...
# 29969538  2018-03-13 16:24:04.880      <0.01  right_only
# 29969539  2018-03-13 16:24:04.880      <0.01  right_only
# 29969540  2018-03-13 16:24:04.880      <0.01  right_only
# 29969541  2018-03-13 16:24:04.880      <0.01  right_only
# 29969542  2018-03-13 16:24:04.880      <0.01  right_only
# 29969543  2018-03-13 16:24:04.880      <0.01  right_only
# 29969544  2018-03-13 16:24:04.880      <0.01  right_only
# 29969545  2018-03-13 16:24:04.880      <0.01  right_only
# 29969546  2018-03-13 16:24:04.880      <0.01  right_only
# 29969547  2018-03-13 16:24:04.880      <0.01  right_only
# 29969548  2018-03-13 16:24:04.880      <0.01  right_only
# 29969549  2018-03-13 16:24:04.880      <0.01  right_only
# 29969550  2018-03-13 16:24:04.880      <0.01  right_only
# 29969551  2018-03-13 16:24:04.880      <0.01  right_only
# 29969552  2018-03-13 16:24:04.880      <0.01  right_only
# 29969553  2018-03-13 16:24:04.880      <0.01  right_only
# 29969554  2018-03-13 16:24:04.880      <0.01  right_only
# 29969555  2018-03-13 16:24:04.880      <0.01  right_only
# 29969556  2018-03-13 16:24:04.880      <0.01  right_only
# 29969557  2018-03-13 16:24:04.880      <0.01  right_only
# 29969558  2018-03-13 16:24:04.880      <0.01  right_only
# 29969559  2018-03-13 16:24:04.880      <0.01  right_only
# 29969560  2018-03-13 16:24:04.880      <0.01  right_only
# 29969561  2018-03-13 16:24:04.880      <0.01  right_only
# 29969562  2018-03-13 16:24:04.880      <0.01  right_only
# 29969563  2018-03-13 16:24:04.880      <0.01  right_only
# 29969564  2018-03-13 16:24:04.880      <0.01  right_only
# 29969565  2018-03-13 16:24:04.880      <0.01  right_only
# 29969566  2018-03-13 16:24:04.880      <0.01  right_only
# 29969567  2018-03-13 16:24:04.880      <0.01  right_only
#
# [3379536 rows x 19 columns]

# %%
bulk_and_algorithm_tags[bulk_and_algorithm_tags['document_type']=='guidance'].content_id.nunique()
# Out:
# 5671

# %%
hard_to_tag = hard_to_tag[hard_to_tag['_merge']=='right_only']

# %%
hard_to_tag[hard_to_tag['document_type']=='guidance'].content_id.nunique()
# Out:
# 635

# %%
hard_to_tag.to_csv(os.path.join(DATADIR, 'hard_to_bulk_algorithm_tag.csv.gz'),compression='gzip',index=False)
