# %%
import numpy as np
import nltk
import pandas as pd
from pandas.io.json import json_normalize

import json
from lxml import etree,html

import os
from collections import Counter,OrderedDict

# %% [markdown]
# ### 1. Read data.

# %%
DATADIR=os.getenv('DATADIR')

# %%
# Get data file locations
CONTENT_INPUT = os.path.join(DATADIR, 'raw_content.json.gz')
CONTENT_OUTPUT = os.path.join(DATADIR, 'clean_content.csv')

# %%
#download the taxon data from content store for all links which are taxons
content = pd.read_json(
    CONTENT_INPUT, 
    orient='table', 
    typ='frame', 
    dtype=True, 
    convert_axes=True, 
    convert_dates=True, 
    keep_default_dates=True, 
    numpy=False, 
    precise_float=False, 
    date_unit=None,
    compression = 'gzip'
)

# %%
content['details'].iloc[0]
# Out:
# {'department_analytics_profile': '',
#  'external_related_links': [],
#  'introductory_paragraph': '<p>Tax your car, motorcycle or other vehicle using a reference number from:</p>\n\n<ul>\n  <li>a recent reminder (V11) or ‘last chance’ warning letter from <abbr title="Driver and Vehicle Licensing Agency">DVLA</abbr>\n</li>\n  <li>your vehicle log book (V5C) - it must be in your name</li>\n  <li>the green ‘new keeper’s details’ slip (V5C/2) from a log book if you’ve just bought it</li>\n</ul>\n\n<p>You can pay by debit or credit card, or Direct Debit.</p>\n\n<div role="note" aria-label="Information" class="application-notice info-notice">\n<p>This service is also available <a href="/treth-car">in Welsh</a>.</p>\n</div>\n\n<p>You’ll need to meet all the <a href="/legal-obligations-drivers-riders">legal obligations for drivers</a> before you can drive.</p>\n\n<div role="note" aria-label="Help" class="application-notice help-notice">\n<p>You must tax your vehicle, even if you don’t have to pay.</p>\n</div>\n\n',
#  'other_ways_to_apply': '\n<div class="contact">\n<p><strong><abbr title="Driver and Vehicle Licensing Agency">DVLA</abbr> vehicle tax service</strong><br>\nTelephone: 0300 123 4321<br>\n24-hour service<br>\n<a href="/call-charges">Find out about call charges</a></p>\n</div>\n\n<p>You can’t pay by Direct Debit over the phone.</p>\n\n<h3 id="at-a-post-office">At a Post Office</h3>\n\n<p>Go to a <a rel="external" href="http://www.postoffice.co.uk/branch-finder">Post Office</a> that deals with vehicle tax. You need to take either:</p>\n\n<ul>\n  <li>the <a href="/vehicle-tax-rate-tables">payment for your vehicle tax</a>\n</li>\n  <li>your bank or building society account details to set up a Direct Debit</li>\n</ul>\n\n<p>You also need to take one of the following:</p>\n\n<ul>\n  <li>your vehicle log book (V5C) (it must be in your name)</li>\n  <li>the green ‘new keeper’s details’ slip (V5C/2) from a log book if you’ve just bought it</li>\n</ul>\n\n<div role="note" aria-label="Information" class="application-notice info-notice">\n<p>If you don’t have any of these documents, you’ll need to <a href="/vehicle-log-book">apply for a new log book</a>.</p>\n</div>\n\n<p>You might also need your MOT test certificate (it must be valid when the tax starts).</p>\n\n<div role="note" aria-label="Information" class="application-notice info-notice">\n<p>It can take up to 2 days for MOT information to be updated, so you might not be able to tax your vehicle immediately after it passes its test.</p>\n</div>\n\n<p>In Northern Ireland you also need an insurance certificate or cover note.</p>\n\n<h2 id="if-the-vehicle-is-off-the-road">If the vehicle is off the road</h2>\n\n<p><a href="/make-a-sorn">Register that your vehicle is off the road</a>, for example you’re keeping it in a garage. You don’t need to tax your vehicle.</p>\n\n',
#  'start_button_text': 'Start now',
#  'transaction_start_link': 'https://www.vehicletax.service.gov.uk',
#  'will_continue_on': ''}

# %%
content.columns
# Out:
# Index(['base_path', 'content_id', 'description', 'details', 'document_type',
#        'first_published_at', 'locale', 'primary_publishing_organisation',
#        'publishing_app', 'taxons', 'title'],
#       dtype='object')

# %% [markdown]
# Redirects dropped because they have no assigned taxons.

# %%
### Redirects have no taxons.
content['taxons'].loc[content['document_type']=='redirect'].isna().sum()
# Out:
# 1689

# %%
print("DROP REDIRECTS")
print("BEFORE:",content.shape)
content = content[content.document_type != "redirect"]
print("AFTER:",content.shape)
# Out:
# DROP REDIRECTS
# BEFORE: (197773, 11)
# AFTER: (196084, 11)

# %%
ids = content["content_id"]
content[ids.isin(ids[ids.duplicated()])].sort_values('content_id')
# Out:
#                                                 base_path  \
# 160721    /government/publications/patent-decision-o14895
# 159553    /government/publications/patent-decision-o14895
# 159355    /government/publications/patent-decision-o02091
# 160714    /government/publications/patent-decision-o02091
# 160720  /government/publications/patent-journal-specia...
# 159552  /government/publications/patent-journal-specia...
# 90930   /guidance/saint-vincent-and-the-grenadines-mig...
# 90918   /guidance/saint-vincent-and-the-grenadines-mig...
# 160715    /government/publications/patent-decision-o19092
# 159356    /government/publications/patent-decision-o19092
# 160722    /government/publications/patent-decision-o01190
# 159354    /government/publications/patent-decision-o01190
# 160762  /government/publications/al7-1an-gilbertson-an...
# 160455  /government/publications/al7-1an-gilbertson-an...
# 159359  /government/publications/patents-journal-speci...
# 160716  /government/publications/patents-journal-speci...
# 159545    /government/publications/patent-decision-o13394
# 160724    /government/publications/patent-decision-o13394
# 160723  /government/news/launch-of-online-digital-serv...
# 159598  /government/news/launch-of-online-digital-serv...
# 160768  /government/publications/pe8-6nu-mick-george-l...
# 160461  /government/publications/pe8-6nu-mick-george-l...
# 159596  /government/publications/df55-notice-of-appeal...
# 160725  /government/publications/df55-notice-of-appeal...
# 160717  /government/publications/design-hearing-decisi...
# 159540  /government/publications/design-hearing-decisi...
# 90926             /guidance/mongolia-migrant-health-guide
# 90935             /guidance/mongolia-migrant-health-guide
# 160719  /government/publications/number-of-patents-gra...
# 159542  /government/publications/number-of-patents-gra...
# ...                                                   ...
# 125862  /government/consultations/rail-franchise-merge...
# 125965  /government/consultations/rail-franchise-merge...
# 125868  /government/news/revamped-website-collects-con...
# 125955  /government/news/revamped-website-collects-con...
# 125854  /government/news/cma-publishes-statement-of-is...
# 125957  /government/news/cma-publishes-statement-of-is...
# 125872  /government/news/merger-of-toy-suppliers-refer...
# 125956  /government/news/merger-of-toy-suppliers-refer...
# 160761  /government/publications/ch2-4nr-ince-park-ren...
# 160449  /government/publications/ch2-4nr-ince-park-ren...
# 90933               /guidance/rwanda-migrant-health-guide
# 90921               /guidance/rwanda-migrant-health-guide
# 160442  /government/publications/wr8-9he-mr-simon-jame...
# 160763  /government/publications/wr8-9he-mr-simon-jame...
# 160443  /government/publications/ex13-5se-greengate-en...
# 160739  /government/publications/ex13-5se-greengate-en...
# 160448  /government/publications/dn19-7nq-elsham-linc-...
# 160760  /government/publications/dn19-7nq-elsham-linc-...
# 160460  /government/publications/nr34-8nq-mr-joe-stent...
# 160767  /government/publications/nr34-8nq-mr-joe-stent...
# 160695  /government/news/first-fine-issued-against-rog...
# 159533  /government/news/first-fine-issued-against-rog...
# 125923  /government/news/east-of-england-lawyers-asked...
# 125902  /government/news/east-of-england-lawyers-asked...
# 90922              /guidance/grenada-migrant-health-guide
# 90929              /guidance/grenada-migrant-health-guide
# 160446  /government/publications/yo61-1ra-h-barker-son...
# 160765  /government/publications/yo61-1ra-h-barker-son...
# 160479  /government/publications/tr12-7az-mrs-kate-wil...
# 160751  /government/publications/tr12-7az-mrs-kate-wil...
#
#                                   content_id  \
# 160721  04c0a94c-5a58-42f3-a791-1f172f637d3a
# 159553  04c0a94c-5a58-42f3-a791-1f172f637d3a
# 159355  04c3c441-c6d1-48aa-9d73-94f7742c7372
# 160714  04c3c441-c6d1-48aa-9d73-94f7742c7372
# 160720  05082ba4-077e-4bed-ba5d-ad67365dd62b
# 159552  05082ba4-077e-4bed-ba5d-ad67365dd62b
# 90930   050997c8-f7cc-48de-bebb-285067b3b6a0
# 90918   050997c8-f7cc-48de-bebb-285067b3b6a0
# 160715  0584f7ec-4af6-4e72-bc3f-c9ee7dddae25
# 159356  0584f7ec-4af6-4e72-bc3f-c9ee7dddae25
# 160722  05a1a417-f7dd-4f9e-9063-560211176ac3
# 159354  05a1a417-f7dd-4f9e-9063-560211176ac3
# 160762  05e06780-39e2-4a22-90e2-fe4c6aa03be7
# 160455  05e06780-39e2-4a22-90e2-fe4c6aa03be7
# 159359  075cc85f-87d4-4687-897f-1047773a6780
# 160716  075cc85f-87d4-4687-897f-1047773a6780
# 159545  09767cc5-4d2e-48af-a1ba-f67e6f2b959d
# 160724  09767cc5-4d2e-48af-a1ba-f67e6f2b959d
# 160723  0cdb9f0d-8f21-4c0f-8eb2-9fe272678c6b
# 159598  0cdb9f0d-8f21-4c0f-8eb2-9fe272678c6b
# 160768  0da4521e-8f52-4f5a-83e4-20972f29fdf6
# 160461  0da4521e-8f52-4f5a-83e4-20972f29fdf6
# 159596  11aa5d25-bd3c-4169-b440-01b9fcdc4972
# 160725  11aa5d25-bd3c-4169-b440-01b9fcdc4972
# 160717  11bba905-6c57-45d8-8b8e-41fc3e705bbd
# 159540  11bba905-6c57-45d8-8b8e-41fc3e705bbd
# 90926   1274a93c-2cd2-434a-9ef5-2c03f938c8bf
# 90935   1274a93c-2cd2-434a-9ef5-2c03f938c8bf
# 160719  12a219cd-b6c1-4d44-8ef1-63675a48718a
# 159542  12a219cd-b6c1-4d44-8ef1-63675a48718a
# ...                                      ...
# 125862  d522c1ff-9c9c-4ff3-89f2-7eb139e8d463
# 125965  d522c1ff-9c9c-4ff3-89f2-7eb139e8d463
# 125868  d60cf9e8-5db7-4416-bdb3-a78a26714736
# 125955  d60cf9e8-5db7-4416-bdb3-a78a26714736
# 125854  da563677-5b07-48c0-b506-b25a4e263eda
# 125957  da563677-5b07-48c0-b506-b25a4e263eda
# 125872  dcc45415-3b01-4fe1-a501-e2a982858c04
# 125956  dcc45415-3b01-4fe1-a501-e2a982858c04
# 160761  dd331261-e8bc-4e9b-95b6-449e2a49383c
# 160449  dd331261-e8bc-4e9b-95b6-449e2a49383c
# 90933   dd5d339c-9dce-4f84-8a1e-316daedc850f
# 90921   dd5d339c-9dce-4f84-8a1e-316daedc850f
# 160442  df86a68d-70e1-4db5-b2f7-0510f21c1711
# 160763  df86a68d-70e1-4db5-b2f7-0510f21c1711
# 160443  e54c5ebb-9a14-4830-a588-161729886add
# 160739  e54c5ebb-9a14-4830-a588-161729886add
# 160448  e5f376da-d2c8-4523-8cdf-82aced385767
# 160760  e5f376da-d2c8-4523-8cdf-82aced385767
# 160460  e9317120-a2ec-4bbc-a939-cb1b717c72a7
# 160767  e9317120-a2ec-4bbc-a939-cb1b717c72a7
# 160695  e9c35be3-e74c-4bf5-b55e-2113d4106b86
# 159533  e9c35be3-e74c-4bf5-b55e-2113d4106b86
# 125923  ec3c821d-6229-4e1c-9290-eb07f4f3d953
# 125902  ec3c821d-6229-4e1c-9290-eb07f4f3d953
# 90922   ee7c8f92-9f30-47d9-aacd-e3c03bb97e91
# 90929   ee7c8f92-9f30-47d9-aacd-e3c03bb97e91
# 160446  f07eb708-2a30-4161-ac9e-3b5157f5c35e
# 160765  f07eb708-2a30-4161-ac9e-3b5157f5c35e
# 160479  f584a79d-a15f-49c3-887e-1717954fe08f
# 160751  f584a79d-a15f-49c3-887e-1717954fe08f
#
#                                               description  \
# 160721  Decision outcome on patent application no 9104...
# 159553  Decision outcome on patent application no 9104...
# 159355  Decision outcome on application for the revoca...
# 160714  Decision outcome on application for the revoca...
# 160720                    Publication date 26 April 2017.
# 159552                    Publication date 26 April 2017.
# 90930   Advice and guidance on the health needs of mig...
# 90918   Advice and guidance on the health needs of mig...
# 160715  Decision outcome on application for revocation...
# 159356  Decision outcome on application for revocation...
# 160722  Decision outcome on revocation of Patent no 20...
# 159354  Decision outcome on revocation of Patent no 20...
# 160762  View the application submitted by Gilbertson a...
# 160455  View the application submitted by Gilbertson a...
# 159359                 Publication date 18 February 2015.
# 160716                 Publication date 18 February 2015.
# 159545  Decision outcome of an application under secti...
# 160724  Decision outcome of an application under secti...
# 160723  New online service to allow customers to regis...
# 159598  New online service to allow customers to regis...
# 160768  View the application submitted by Mick George ...
# 160461  View the application submitted by Mick George ...
# 159596  Use this form to appeal a decision to the appo...
# 160725  Use this form to appeal a decision to the appo...
# 160717  Outcome of request to invalidate, hearing held...
# 159540  Outcome of request to invalidate, hearing held...
# 90926   Advice and guidance on the health needs of mig...
# 90935   Advice and guidance on the health needs of mig...
# 160719  Request for number of UK patents were granted ...
# 159542  Request for number of UK patents were granted ...
# ...                                                   ...
# 125862  Consultation on proposed guidance for the eval...
# 125965  Consultation on proposed guidance for the eval...
# 125868  Consumer protection agencies from 34 countries...
# 125955  Consumer protection agencies from 34 countries...
# 125854  The CMA has published an issues statement foll...
# 125957  The CMA has published an issues statement foll...
# 125872  The CMA has referred VTech’s acquisition of Le...
# 125956  The CMA has referred VTech’s acquisition of Le...
# 160761  View the application submitted by Ince Park Re...
# 160449  View the application submitted by Ince Park Re...
# 90933   Advice and guidance on the health needs of mig...
# 90921   Advice and guidance on the health needs of mig...
# 160442  View the application submitted by Mr Simon Jam...
# 160763  View the application submitted by Mr Simon Jam...
# 160443  View the application submitted by Greengate En...
# 160739  View the application submitted by Greengate En...
# 160448  View the application submitted by Elsham Linc ...
# 160760  View the application submitted by Elsham Linc ...
# 160460  View the application submitted by Mr Joe Stent...
# 160767  View the application submitted by Mr Joe Stent...
# 160695  A firm responsible for bombarding people with ...
# 159533  A firm responsible for bombarding people with ...
# 125923  Lawyers in the East of England are being asked...
# 125902  Lawyers in the East of England are being asked...
# 90922   Advice and guidance on the health needs of mig...
# 90929   Advice and guidance on the health needs of mig...
# 160446  View the application submitted by H Barker & S...
# 160765  View the application submitted by H Barker & S...
# 160479  View the application submitted by Mrs Kate Wil...
# 160751  View the application submitted by Mrs Kate Wil...
#
#                                                   details      document_type  \
# 160721  {'government': {'slug': '1992-to-1997-conserva...           decision
# 159553  {'government': {'slug': '1992-to-1997-conserva...           decision
# 159355  {'government': {'slug': '1987-to-1992-conserva...           decision
# 160714  {'government': {'slug': '1987-to-1992-conserva...           decision
# 160720  {'government': {'slug': '2015-conservative-gov...             notice
# 159552  {'government': {'slug': '2015-conservative-gov...             notice
# 90930   {'government': {'slug': '2010-to-2015-conserva...     detailed_guide
# 90918   {'government': {'slug': '2010-to-2015-conserva...     detailed_guide
# 160715  {'government': {'slug': '1992-to-1997-conserva...           decision
# 159356  {'government': {'slug': '1992-to-1997-conserva...           decision
# 160722  {'government': {'slug': '1987-to-1992-conserva...           decision
# 159354  {'government': {'slug': '1987-to-1992-conserva...           decision
# 160762  {'government': {'slug': '2015-conservative-gov...             notice
# 160455  {'government': {'slug': '2015-conservative-gov...             notice
# 159359  {'government': {'slug': '2010-to-2015-conserva...             notice
# 160716  {'government': {'slug': '2010-to-2015-conserva...             notice
# 159545  {'government': {'slug': '1992-to-1997-conserva...           decision
# 160724  {'government': {'slug': '1992-to-1997-conserva...           decision
# 160723  {'government': {'slug': '2015-conservative-gov...         news_story
# 159598  {'government': {'slug': '2015-conservative-gov...         news_story
# 160768  {'government': {'slug': '2015-conservative-gov...             notice
# 160461  {'government': {'slug': '2015-conservative-gov...             notice
# 159596  {'government': {'slug': '2010-to-2015-conserva...               form
# 160725  {'government': {'slug': '2010-to-2015-conserva...               form
# 160717  {'government': {'slug': '2015-conservative-gov...           decision
# 159540  {'government': {'slug': '2015-conservative-gov...           decision
# 90926   {'government': {'slug': '2010-to-2015-conserva...     detailed_guide
# 90935   {'government': {'slug': '2010-to-2015-conserva...     detailed_guide
# 160719  {'government': {'slug': '2010-to-2015-conserva...        foi_release
# 159542  {'government': {'slug': '2010-to-2015-conserva...        foi_release
# ...                                                   ...                ...
# 125862  {'government': {'slug': '2015-conservative-gov...  open_consultation
# 125965  {'government': {'slug': '2015-conservative-gov...  open_consultation
# 125868  {'government': {'slug': '2015-conservative-gov...      press_release
# 125955  {'government': {'slug': '2015-conservative-gov...      press_release
# 125854  {'government': {'slug': '2010-to-2015-conserva...         news_story
# 125957  {'government': {'slug': '2010-to-2015-conserva...         news_story
# 125872  {'government': {'slug': '2015-conservative-gov...         news_story
# 125956  {'government': {'slug': '2015-conservative-gov...         news_story
# 160761  {'government': {'slug': '2015-conservative-gov...             notice
# 160449  {'government': {'slug': '2015-conservative-gov...             notice
# 90933   {'government': {'slug': '2010-to-2015-conserva...     detailed_guide
# 90921   {'government': {'slug': '2010-to-2015-conserva...     detailed_guide
# 160442  {'government': {'slug': '2015-conservative-gov...             notice
# 160763  {'government': {'slug': '2015-conservative-gov...             notice
# 160443  {'government': {'slug': '2015-conservative-gov...             notice
# 160739  {'government': {'slug': '2015-conservative-gov...             notice
# 160448  {'government': {'slug': '2015-conservative-gov...             notice
# 160760  {'government': {'slug': '2015-conservative-gov...             notice
# 160460  {'government': {'slug': '2015-conservative-gov...             notice
# 160767  {'government': {'slug': '2015-conservative-gov...             notice
# 160695  {'government': {'slug': '2015-conservative-gov...      press_release
# 159533  {'government': {'slug': '2015-conservative-gov...      press_release
# 125923  {'government': {'slug': '2015-conservative-gov...      press_release
# 125902  {'government': {'slug': '2015-conservative-gov...      press_release
# 90922   {'government': {'slug': '2010-to-2015-conserva...     detailed_guide
# 90929   {'government': {'slug': '2010-to-2015-conserva...     detailed_guide
# 160446  {'government': {'slug': '2015-conservative-gov...             notice
# 160765  {'government': {'slug': '2015-conservative-gov...             notice
# 160479  {'government': {'slug': '2015-conservative-gov...             notice
# 160751  {'government': {'slug': '2015-conservative-gov...             notice
#
#                    first_published_at locale  \
# 160721  1995-10-30T00:00:00.000+00:00     en
# 159553  1995-10-30T00:00:00.000+00:00     en
# 159355  1991-01-29T00:00:00.000+00:00     en
# 160714  1991-01-29T00:00:00.000+00:00     en
# 160720  2017-04-26T03:30:05.000+00:00     en
# 159552  2017-04-26T03:30:05.000+00:00     en
# 90930   2014-07-30T23:00:00.000+00:00     en
# 90918   2014-07-30T23:00:00.000+00:00     en
# 160715  1992-11-19T00:00:00.000+00:00     en
# 159356  1992-11-19T00:00:00.000+00:00     en
# 160722  1989-12-21T00:00:00.000+00:00     en
# 159354  1989-12-21T00:00:00.000+00:00     en
# 160762  2017-10-03T12:42:00.000+00:00     en
# 160455  2017-10-03T12:42:00.000+00:00     en
# 159359  2015-02-18T04:30:21.000+00:00     en
# 160716  2015-02-18T04:30:21.000+00:00     en
# 159545  1994-09-05T23:00:00.000+00:00     en
# 160724  1994-09-05T23:00:00.000+00:00     en
# 160723  2015-09-30T09:12:36.000+00:00     en
# 159598  2015-09-30T09:12:36.000+00:00     en
# 160768  2017-10-10T13:04:00.000+00:00     en
# 160461  2017-10-10T13:04:00.000+00:00     en
# 159596  2015-04-24T12:50:49.000+00:00     en
# 160725  2015-04-24T12:50:49.000+00:00     en
# 160717  2016-02-03T13:55:03.000+00:00     en
# 159540  2016-02-03T13:55:03.000+00:00     en
# 90926   2014-07-30T23:00:00.000+00:00     en
# 90935   2014-07-30T23:00:00.000+00:00     en
# 160719  2015-01-21T12:06:00.000+00:00     en
# 159542  2015-01-21T12:06:00.000+00:00     en
# ...                               ...    ...
# 125862  2017-10-18T11:01:23.000+00:00     en
# 125965  2017-10-18T11:01:23.000+00:00     en
# 125868  2015-10-13T15:07:59.000+00:00     en
# 125955  2015-10-13T15:07:59.000+00:00     en
# 125854  2015-02-05T15:53:00.000+00:00     en
# 125957  2015-02-05T15:53:00.000+00:00     en
# 125872  2016-08-30T09:31:50.000+00:00     en
# 125956  2016-08-30T09:31:50.000+00:00     en
# 160761  2017-10-03T12:39:08.000+00:00     en
# 160449  2017-10-03T12:39:08.000+00:00     en
# 90933   2014-07-30T23:00:00.000+00:00     en
# 90921   2014-07-30T23:00:00.000+00:00     en
# 160442  2017-10-18T15:25:48.000+00:00     en
# 160763  2017-10-18T15:25:48.000+00:00     en
# 160443  2017-11-07T14:35:39.000+00:00     en
# 160739  2017-11-07T14:35:39.000+00:00     en
# 160448  2017-10-04T12:02:51.000+00:00     en
# 160760  2017-10-04T12:02:51.000+00:00     en
# 160460  2017-10-13T09:52:27.000+00:00     en
# 160767  2017-10-13T09:52:27.000+00:00     en
# 160695  2015-08-05T09:05:00.000+00:00     en
# 159533  2015-08-05T09:05:00.000+00:00     en
# 125923  2016-11-16T13:00:09.000+00:00     en
# 125902  2016-11-16T13:00:09.000+00:00     en
# 90922   2014-07-30T23:00:00.000+00:00     en
# 90929   2014-07-30T23:00:00.000+00:00     en
# 160446  2017-10-18T11:55:00.000+00:00     en
# 160765  2017-10-18T11:55:00.000+00:00     en
# 160479  2017-11-02T17:09:15.000+00:00     en
# 160751  2017-11-02T17:09:15.000+00:00     en
#
#                        primary_publishing_organisation publishing_app  \
# 160721       {'title': 'Intellectual Property Office'}      whitehall
# 159553       {'title': 'Intellectual Property Office'}      whitehall
# 159355       {'title': 'Intellectual Property Office'}      whitehall
# 160714       {'title': 'Intellectual Property Office'}      whitehall
# 160720       {'title': 'Intellectual Property Office'}      whitehall
# 159552       {'title': 'Intellectual Property Office'}      whitehall
# 90930               {'title': 'Public Health England'}      whitehall
# 90918               {'title': 'Public Health England'}      whitehall
# 160715       {'title': 'Intellectual Property Office'}      whitehall
# 159356       {'title': 'Intellectual Property Office'}      whitehall
# 160722       {'title': 'Intellectual Property Office'}      whitehall
# 159354       {'title': 'Intellectual Property Office'}      whitehall
# 160762                 {'title': 'Environment Agency'}      whitehall
# 160455                 {'title': 'Environment Agency'}      whitehall
# 159359       {'title': 'Intellectual Property Office'}      whitehall
# 160716       {'title': 'Intellectual Property Office'}      whitehall
# 159545       {'title': 'Intellectual Property Office'}      whitehall
# 160724       {'title': 'Intellectual Property Office'}      whitehall
# 160723       {'title': 'Intellectual Property Office'}      whitehall
# 159598       {'title': 'Intellectual Property Office'}      whitehall
# 160768                 {'title': 'Environment Agency'}      whitehall
# 160461                 {'title': 'Environment Agency'}      whitehall
# 159596       {'title': 'Intellectual Property Office'}      whitehall
# 160725       {'title': 'Intellectual Property Office'}      whitehall
# 160717       {'title': 'Intellectual Property Office'}      whitehall
# 159540       {'title': 'Intellectual Property Office'}      whitehall
# 90926               {'title': 'Public Health England'}      whitehall
# 90935               {'title': 'Public Health England'}      whitehall
# 160719       {'title': 'Intellectual Property Office'}      whitehall
# 159542       {'title': 'Intellectual Property Office'}      whitehall
# ...                                                ...            ...
# 125862  {'title': 'Competition and Markets Authority'}      whitehall
# 125965  {'title': 'Competition and Markets Authority'}      whitehall
# 125868  {'title': 'Competition and Markets Authority'}      whitehall
# 125955  {'title': 'Competition and Markets Authority'}      whitehall
# 125854  {'title': 'Competition and Markets Authority'}      whitehall
# 125957  {'title': 'Competition and Markets Authority'}      whitehall
# 125872  {'title': 'Competition and Markets Authority'}      whitehall
# 125956  {'title': 'Competition and Markets Authority'}      whitehall
# 160761                 {'title': 'Environment Agency'}      whitehall
# 160449                 {'title': 'Environment Agency'}      whitehall
# 90933               {'title': 'Public Health England'}      whitehall
# 90921               {'title': 'Public Health England'}      whitehall
# 160442                 {'title': 'Environment Agency'}      whitehall
# 160763                 {'title': 'Environment Agency'}      whitehall
# 160443                 {'title': 'Environment Agency'}      whitehall
# 160739                 {'title': 'Environment Agency'}      whitehall
# 160448                 {'title': 'Environment Agency'}      whitehall
# 160760                 {'title': 'Environment Agency'}      whitehall
# 160460                 {'title': 'Environment Agency'}      whitehall
# 160767                 {'title': 'Environment Agency'}      whitehall
# 160695                {'title': 'Ministry of Justice'}      whitehall
# 159533                {'title': 'Ministry of Justice'}      whitehall
# 125923  {'title': 'Competition and Markets Authority'}      whitehall
# 125902  {'title': 'Competition and Markets Authority'}      whitehall
# 90922               {'title': 'Public Health England'}      whitehall
# 90929               {'title': 'Public Health England'}      whitehall
# 160446                 {'title': 'Environment Agency'}      whitehall
# 160765                 {'title': 'Environment Agency'}      whitehall
# 160479                 {'title': 'Environment Agency'}      whitehall
# 160751                 {'title': 'Environment Agency'}      whitehall
#
#                                                    taxons  \
# 160721  [{'content_id': '21eee04d-e702-4e7b-9fde-2f677...
# 159553  [{'content_id': '21eee04d-e702-4e7b-9fde-2f677...
# 159355  [{'content_id': '21eee04d-e702-4e7b-9fde-2f677...
# 160714  [{'content_id': '21eee04d-e702-4e7b-9fde-2f677...
# 160720                                                NaN
# 159552                                                NaN
# 90930   [{'content_id': 'd6a4884e-769d-4b81-8ba5-b6439...
# 90918   [{'content_id': 'd6a4884e-769d-4b81-8ba5-b6439...
# 160715  [{'content_id': '21eee04d-e702-4e7b-9fde-2f677...
# 159356  [{'content_id': '21eee04d-e702-4e7b-9fde-2f677...
# 160722                                                NaN
# 159354                                                NaN
# 160762                                                NaN
# 160455                                                NaN
# 159359                                                NaN
# 160716                                                NaN
# 159545                                                NaN
# 160724                                                NaN
# 160723  [{'content_id': '21eee04d-e702-4e7b-9fde-2f677...
# 159598  [{'content_id': '21eee04d-e702-4e7b-9fde-2f677...
# 160768                                                NaN
# 160461                                                NaN
# 159596                                                NaN
# 160725                                                NaN
# 160717                                                NaN
# 159540                                                NaN
# 90926   [{'content_id': 'd6a4884e-769d-4b81-8ba5-b6439...
# 90935   [{'content_id': 'd6a4884e-769d-4b81-8ba5-b6439...
# 160719  [{'content_id': 'f3f4b5d3-49c4-487b-bd5b-be75f...
# 159542  [{'content_id': 'f3f4b5d3-49c4-487b-bd5b-be75f...
# ...                                                   ...
# 125862  [{'content_id': 'a3773f5e-f05e-48b0-b79a-46374...
# 125965  [{'content_id': 'a3773f5e-f05e-48b0-b79a-46374...
# 125868  [{'content_id': '8c19f8a6-35c0-4e00-98fd-870fe...
# 125955  [{'content_id': '8c19f8a6-35c0-4e00-98fd-870fe...
# 125854  [{'content_id': 'a3773f5e-f05e-48b0-b79a-46374...
# 125957  [{'content_id': 'a3773f5e-f05e-48b0-b79a-46374...
# 125872  [{'content_id': 'a3773f5e-f05e-48b0-b79a-46374...
# 125956  [{'content_id': 'a3773f5e-f05e-48b0-b79a-46374...
# 160761                                                NaN
# 160449                                                NaN
# 90933   [{'content_id': 'd6a4884e-769d-4b81-8ba5-b6439...
# 90921   [{'content_id': 'd6a4884e-769d-4b81-8ba5-b6439...
# 160442                                                NaN
# 160763                                                NaN
# 160443                                                NaN
# 160739                                                NaN
# 160448                                                NaN
# 160760                                                NaN
# 160460                                                NaN
# 160767                                                NaN
# 160695  [{'content_id': 'da0bc015-f8e5-492c-8d81-6fbf9...
# 159533  [{'content_id': 'da0bc015-f8e5-492c-8d81-6fbf9...
# 125923  [{'content_id': '900ee60d-32ed-4dba-9834-09f54...
# 125902  [{'content_id': '900ee60d-32ed-4dba-9834-09f54...
# 90922   [{'content_id': 'd6a4884e-769d-4b81-8ba5-b6439...
# 90929   [{'content_id': 'd6a4884e-769d-4b81-8ba5-b6439...
# 160446                                                NaN
# 160765                                                NaN
# 160479                                                NaN
# 160751                                                NaN
#
#                                                     title
# 160721                          Patent decision: O/148/95
# 159553                          Patent decision: O/148/95
# 159355                          Patent decision: O/020/91
# 160714                          Patent decision: O/020/91
# 160720               Patent Journal special notices: 6675
# 159552               Patent Journal special notices: 6675
# 90930   Saint Vincent and the Grenadines: migrant heal...
# 90918   Saint Vincent and the Grenadines: migrant heal...
# 160715                          Patent decision: O/190/92
# 159356                          Patent decision: O/190/92
# 160722                          Patent decision: O/011/90
# 159354                          Patent decision: O/011/90
# 160762  AL7 1AN, Gilbertson and Page Limited: environm...
# 160455  AL7 1AN, Gilbertson and Page Limited: environm...
# 159359              Patents Journal special notices: 6561
# 160716              Patents Journal special notices: 6561
# 159545                          Patent decision: O/133/94
# 160724                          Patent decision: O/133/94
# 160723       Launch of online digital service for designs
# 159598       Launch of online digital service for designs
# 160768  PE8 6NU, Mick George Limited: environmental pe...
# 160461  PE8 6NU, Mick George Limited: environmental pe...
# 159596     DF55: Notice of appeal to the appointed person
# 160725     DF55: Notice of appeal to the appointed person
# 160717                  Design hearing decision: O/046/16
# 159540                  Design hearing decision: O/046/16
# 90926                      Mongolia: migrant health guide
# 90935                      Mongolia: migrant health guide
# 160719  Number of patents granted 1993 to 2012 by gend...
# 159542  Number of patents granted 1993 to 2012 by gend...
# ...                                                   ...
# 125862                    Rail franchise mergers guidance
# 125965                    Rail franchise mergers guidance
# 125868  Revamped website collects consumer cross-borde...
# 125955  Revamped website collects consumer cross-borde...
# 125854  CMA publishes statement of issues over lubrica...
# 125957  CMA publishes statement of issues over lubrica...
# 125872  Merger of toy suppliers referred for in-depth ...
# 125956  Merger of toy suppliers referred for in-depth ...
# 160761  CH2 4NR, Ince Park Renewables Limited: environ...
# 160449  CH2 4NR, Ince Park Renewables Limited: environ...
# 90933                        Rwanda: migrant health guide
# 90921                        Rwanda: migrant health guide
# 160442  WR8 9HE, Mr Simon James: environmental permit ...
# 160763  WR8 9HE, Mr Simon James: environmental permit ...
# 160443  EX13 5SE, Greengate Enterprise Limited: enviro...
# 160739  EX13 5SE, Greengate Enterprise Limited: enviro...
# 160448  DN19 7NQ, Elsham Linc Limited: environmental p...
# 160760  DN19 7NQ, Elsham Linc Limited: environmental p...
# 160460  NR34 8NQ, Mr Joe Stent: environmental permit a...
# 160767  NR34 8NQ, Mr Joe Stent: environmental permit a...
# 160695  First fine issued against rogue claims managem...
# 159533  First fine issued against rogue claims managem...
# 125923  East of England lawyers asked to help competit...
# 125902  East of England lawyers asked to help competit...
# 90922                       Grenada: migrant health guide
# 90929                       Grenada: migrant health guide
# 160446  YO61 1RA, H Barker & Son Limited: environmenta...
# 160765  YO61 1RA, H Barker & Son Limited: environmenta...
# 160479  TR12 7AZ, Mrs Kate Wilson: environmental permi...
# 160751  TR12 7AZ, Mrs Kate Wilson: environmental permi...
#
# [849 rows x 11 columns]

# %% [markdown]
# ### 2. Extract page text from nested json.

# %% [markdown]
# Some preliminary counting, nothing that should be ultimately run.

# %%
total_tags = Counter()
total_types = Counter()
sub_types = Counter()

# %%
r = json.dumps(content['details'][0])
loaded_r = json.loads(r)
print(loaded_r.keys())
# Out:
# dict_keys(['other_ways_to_apply', 'start_button_text', 'department_analytics_profile', 'will_continue_on', 'transaction_start_link', 'external_related_links', 'introductory_paragraph'])

# %% [markdown]
# #### 2.1 Bool checks for json/html.

# %% [markdown]
# Checks for json and html strings.

# %%
def is_json(raw_text):
    try:
        json_normalize(raw_text).columns.tolist()
    except AttributeError:
#         print("exception @ success:",raw_text)
        return False
    return True

def is_html(raw_text):
#     print(raw_text)
#     print(type(raw_text))
    return html.fromstring(str(raw_text)).find('.//*') is not None

# %% [markdown]
# #### 2.2 Main function for text extraction.

# %% [markdown]
# Tags of main interest, manually discovered.

# %%
# look = ['title', 'note', 'text', 'preposition', 'change_note', 'child_sections', 'abbreviation', 'headers']
look = ['text', 'child_sections', 'headers']
child_keys = ['title','description']
filtered = ['body','brand','documents','final_outcome_detail','final_outcome_documents',
            'government','headers','introduction','introductory_paragraph',
            'licence_overview','licence_short_description','logo','metadata','more_information','need_to_know',
            'other_ways_to_apply','summary','ways_to_respond','what_you_need_to_know','will_continue_on']

# %% [markdown]
# Heuristics include length of strings and json keys listed above.

# %%
def nested_extract(x):
    ttext = ""
    string_json2 = json.dumps(OrderedDict(x))
    order_json2 = json.loads(string_json2,object_pairs_hook=OrderedDict)
    if 'body' in order_json2.keys() and isinstance(order_json2['body'],str):
        raw_string2 = extract_text(order_json2['body'])
        if len(raw_string2.split(" ")) > 10:
                ttext += " " + raw_string2
    elif 'child_sections' in order_json2.keys(): 
    #                             print(type(order_json2['child_sections']),len(order_json2['child_sections']))
        for child in order_json2['child_sections']:
            for key in child_keys:
                ttext += " " + child[key]
    return ttext

# %%
def get_text(x):
    total_text = ""
    ### From dict to json and back (to OrderedDict).
    string_json = json.dumps(OrderedDict(x))
    order_json = json.loads(string_json,object_pairs_hook=OrderedDict)
    ### Iterate over json from details.
    for key,raw_text in sorted(order_json.items()):
        if key in filtered:
#             print(key,raw_text)
            if isinstance(raw_text,str) and len(raw_text)>1:  
                raw_text = raw_text.replace("-"," ")
                raw_token = raw_text.split(" ")
                if len(raw_token)>0:
                    raw_string = extract_text(raw_text)
                    total_text += " " + raw_string
            elif isinstance(raw_text,list) and len(raw_text)>0:
                for sub_text in raw_text:
                    if is_json(sub_text):
                        total_text += nested_extract(sub_text)
                    elif is_html(sub_text):
                        str_from_html = extract_text(sub_text)
                        total_text += " " + str_from_html
    return total_text.strip()

# %% [markdown]
# #### 2.3 Function for html extraction.

# %%
# Clean the html

def extract_text(body):
    r = None
    #if lxml.html.fromstring(html).find('.//*') is not None:
    # This is horribly hacky. Previously this was failing on single new line
    # characters.
    if body and body!="/n":
        try:
            tree = etree.HTML(body)
#             print(">>>",tree)
            r = tree.xpath('//text()')
            r = ' '.join(r)
            r = r.strip().replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
            r = r.replace('\n', ' ').replace(',', ' ')
            r = r.lower()
            r = ' '.join(r.split())
        except ValueError:
            print("exception @ extract:",type(body),body)
    if not r:
        r = ' '
    return r

# %% [markdown]
# #### 2.4 Map details to dataset `body` column. Takes a while.

# %%
content['body']= content['details'].map(get_text)

# %%
content.head(3)
# Out:
#                                    base_path  \
# 0                               /vehicle-tax
# 1            /student-finance-register-login
# 2  /government/organisations/companies-house
#
#                              content_id  \
# 0  fa748fae-3de4-4266-ae85-0797ada3f40c
# 1  e57daef4-5eb5-431c-b0ad-14119ab0355f
# 2  c36bd301-d0c5-4492-86ad-ee7843b8383b
#
#                                          description  \
# 0  Renew or tax your vehicle for the first time u...
# 1  Your student finance online account - check pa...
# 2                                               None
#
#                                              details document_type  \
# 0  {'other_ways_to_apply': '
# <div class="contact"...   transaction
# 1  {'other_ways_to_apply': '<p>If you can’t apply...   transaction
# 2  {'brand': 'department-for-business-innovation-...  organisation
#
#               first_published_at locale primary_publishing_organisation  \
# 0  2016-02-29T09:24:10.000+00:00     en                             NaN
# 1  2016-02-29T09:24:10.000+00:00     en                             NaN
# 2  2016-02-29T09:24:10.000+00:00     en                             NaN
#
#   publishing_app                                             taxons  \
# 0      publisher  [{'content_id': '948b6dd4-45b3-45ab-a5c6-5dbce...
# 1      publisher  [{'content_id': '64aa6eec-48b5-481d-9131-9c8b6...
# 2      whitehall                                                NaN
#
#                    title                                               body
# 0       Tax your vehicle  tax your car motorcycle or other vehicle using...
# 1  Student finance login  sign in or register for student finance online...
# 2       Companies House           department for business innovation skills

# %%
# (196084, 12)
content.shape

# %% [markdown]
# ### 4. Add `length`, `title`, `description` and `combined_text` columns.
# Column contents:
# * Length: referring to number of words in page.
# * Title: referring to title of page.
# * Description: referring to description page (field may be null, take care).
# * Combined_text: Concatenate `title`, `description` and `body`.

# %% [markdown]
# #### 4.1 Length.

# %%
content['length'] = content['body'].map(lambda x: len(x.split()))

# %% [markdown]
# #### 4.2 Title.

# %%
content = content.assign(title = content['title'].apply(extract_text))

# %% [markdown]
# #### 4.3 Description.

# %%
content = content.assign(description = content['description'].apply(extract_text))

# %% [markdown]
# #### 4.4 Combined text.

# %%
content['combined_text'] = content['title'] + ' ' + content['description'] + ' ' + content['body']

# %%
find_basic_info(0)
# Out:
# BASE PATH:
#  https://www.gov.uk/api/content/vehicle-tax
# =====
# TITLE:
#  tax your vehicle
# =====
# DESCRIPTION:
#  renew or tax your vehicle for the first time using a reminder letter your log book the 'new keeper's details' section of a log book - and how to tax if you don't have any documents
# =====
# DETAILS:
#  {'other_ways_to_apply': '\n<div class="contact">\n<p><strong><abbr title="Driver and Vehicle Licensing Agency">DVLA</abbr> vehicle tax service</strong><br>\nTelephone: 0300 123 4321<br>\n24-hour service<br>\n<a href="/call-charges">Find out about call charges</a></p>\n</div>\n\n<p>You can’t pay by Direct Debit over the phone.</p>\n\n<h3 id="at-a-post-office">At a Post Office</h3>\n\n<p>Go to a <a rel="external" href="http://www.postoffice.co.uk/branch-finder">Post Office</a> that deals with vehicle tax. You need to take either:</p>\n\n<ul>\n  <li>the <a href="/vehicle-tax-rate-tables">payment for your vehicle tax</a>\n</li>\n  <li>your bank or building society account details to set up a Direct Debit</li>\n</ul>\n\n<p>You also need to take one of the following:</p>\n\n<ul>\n  <li>your vehicle log book (V5C) (it must be in your name)</li>\n  <li>the green ‘new keeper’s details’ slip (V5C/2) from a log book if you’ve just bought it</li>\n</ul>\n\n<div role="note" aria-label="Information" class="application-notice info-notice">\n<p>If you don’t have any of these documents, you’ll need to <a href="/vehicle-log-book">apply for a new log book</a>.</p>\n</div>\n\n<p>You might also need your MOT test certificate (it must be valid when the tax starts).</p>\n\n<div role="note" aria-label="Information" class="application-notice info-notice">\n<p>It can take up to 2 days for MOT information to be updated, so you might not be able to tax your vehicle immediately after it passes its test.</p>\n</div>\n\n<p>In Northern Ireland you also need an insurance certificate or cover note.</p>\n\n<h2 id="if-the-vehicle-is-off-the-road">If the vehicle is off the road</h2>\n\n<p><a href="/make-a-sorn">Register that your vehicle is off the road</a>, for example you’re keeping it in a garage. You don’t need to tax your vehicle.</p>\n\n', 'start_button_text': 'Start now', 'department_analytics_profile': '', 'will_continue_on': '', 'introductory_paragraph': '<p>Tax your car, motorcycle or other vehicle using a reference number from:</p>\n\n<ul>\n  <li>a recent reminder (V11) or ‘last chance’ warning letter from <abbr title="Driver and Vehicle Licensing Agency">DVLA</abbr>\n</li>\n  <li>your vehicle log book (V5C) - it must be in your name</li>\n  <li>the green ‘new keeper’s details’ slip (V5C/2) from a log book if you’ve just bought it</li>\n</ul>\n\n<p>You can pay by debit or credit card, or Direct Debit.</p>\n\n<div role="note" aria-label="Information" class="application-notice info-notice">\n<p>This service is also available <a href="/treth-car">in Welsh</a>.</p>\n</div>\n\n<p>You’ll need to meet all the <a href="/legal-obligations-drivers-riders">legal obligations for drivers</a> before you can drive.</p>\n\n<div role="note" aria-label="Help" class="application-notice help-notice">\n<p>You must tax your vehicle, even if you don’t have to pay.</p>\n</div>\n\n', 'external_related_links': [], 'transaction_start_link': 'https://www.vehicletax.service.gov.uk'}
# =====
# BODY:
#  tax your car motorcycle or other vehicle using a reference number from: a recent reminder (v11) or ‘last chance’ warning letter from dvla your vehicle log book (v5c) it must be in your name the green ‘new keeper’s details’ slip (v5c/2) from a log book if you’ve just bought it you can pay by debit or credit card or direct debit. this service is also available in welsh . you’ll need to meet all the legal obligations for drivers before you can drive. you must tax your vehicle even if you don’t have to pay. dvla vehicle tax service telephone: 0300 123 4321 24 hour service find out about call charges you can’t pay by direct debit over the phone. at a post office go to a post office that deals with vehicle tax. you need to take either: the payment for your vehicle tax your bank or building society account details to set up a direct debit you also need to take one of the following: your vehicle log book (v5c) (it must be in your name) the green ‘new keeper’s details’ slip (v5c/2) from a log book if you’ve just bought it if you don’t have any of these documents you’ll need to apply for a new log book . you might also need your mot test certificate (it must be valid when the tax starts). it can take up to 2 days for mot information to be updated so you might not be able to tax your vehicle immediately after it passes its test. in northern ireland you also need an insurance certificate or cover note. if the vehicle is off the road register that your vehicle is off the road for example you’re keeping it in a garage. you don’t need to tax your vehicle.
# =====

# %% [markdown]
# ### 5. Output to csv.

# %%
content['taxons'] = content['taxons'].where((pd.notnull(content['taxons'])), None)

# %%
content.to_csv("clean_content_enrich_test.csv",index=False)

# %%
content = pd.read_csv("clean_content_test.csv")

# %%
content.head()

# %% [markdown]
# ### 4. Taxon work.

# %%
content.columns

# %%
content_columns = content.drop(['taxons'], axis=1).columns.values

# %%
content_wide = pd.concat([content.drop('taxons', axis=1), content['taxons'].apply(pd.Series)], axis=1)

# %%
content_long = pd.melt(content_wide, id_vars=content_columns, value_name='taxon')

# %%
content_long.columns

# %%
content_long['taxon'][4]

# %%
content_wide[0:10]

# %%
mask = content_long['taxon'].isnull()
content_long = content_long[~mask]

# %%
content_long = content_long.assign(taxon_id = [d['content_id'] for d in content_long['taxon']])

# %%
content_long = content_long.drop(['taxon'], axis=1)

# %%
content_long.shape[0]

# %%
content_long.head()

# %%
taxons = pd.read_csv('../../data/clean_taxons.csv')

# %%
taxons = taxons[['base_path','content_id','taxon_name','level1taxon','level2taxon','level3taxon','level4taxon']]

# %%
content_taxons = pd.merge(
    left=content_long, 
    right=taxons, 
    left_on='taxon_id', 
    right_on='content_id', 
    how='outer', 
    indicator=True
)

# %%
content_taxons.head()

# %%
content_taxons.shape

# %%
content_long.shape

# %%
content_taxons['_merge'].value_counts()

# %%
list(content_taxons.columns.values)

# %% [markdown]
# ### 5. Testing.

# %%
body_sample = content['body'][5]
print("https://www.gov.uk"+content['base_path'][5],"\n",body_sample)
print(len(body_sample),body_sample.split(" "))

# %%
content['body'].loc[(content['length']>=1) & (content['length']<=6)]

# %%
content.shape

# %% [markdown]
# #### 5.1 Check out main page features.

# %%
### REF 2023, 8975
def find_basic_info(i):
    print("BASE PATH:\n https://www.gov.uk/api/content"+content['base_path'][i],"\n=====")
    print("TITLE:\n",content['title'][i],"\n=====")
    print("DESCRIPTION:\n",content['description'][i],"\n=====")
    print("DETAILS:\n",content['details'][i],"\n=====")
    print("BODY:\n",content['body'][i],"\n=====")

# %%
find_basic_info(8975)

# %% [markdown]
# #### 5.2 Empty text.

# %%
empty_text = Counter()
base_paths = []

# %%
for tup in content[0:10].itertuples():
    text = get_text(tup[4])
    if len(text)==0:
        empty_text[tup[5]]+=1
        base_paths.append("https://www.gov.uk"+tup[1])

# %%
print(len(base_paths))
empty_text

# %%
for i,(key,value) in zip(range(1,len(empty_text)+1),sorted(empty_text.items(), key=lambda pair: pair[1], reverse=True)):
    print(str(i)+".",key+":",value)

# %%
potential_sub_types

# %% [markdown]
# Counter({'abbreviation': 57,
#          'allowed_values': 224,
#          'base_path': 22710,
#          'body': 16021,
#          'change_note': 22710,
#          'child_sections': 529,
#          'content_id': 1646,
#          'content_type': 1646,
#          'created_at': 1646,
#          'display_as_result_metadata': 1568,
#          'documents': 10550,
#          'filterable': 1568,
#          'headers': 932,
#          'id': 11890,
#          'key': 1568,
#          'kind': 1427,
#          'level': 11890,
#          'name': 896,
#          'note': 283201,
#          'options': 1427,
#          'preposition': 672,
#          'public_timestamp': 283201,
#          'published_at': 22710,
#          'section_id': 20483,
#          'short_name': 448,
#          'slug': 5873,
#          'text': 11890,
#          'title': 41303,
#          'type': 1120,
#          'updated_at': 1646,
#          'url': 1794,
#          'web_url': 57})

# %% [markdown]
# ### Out of 1000 rows
#
# Counter({'abbreviation': 3,
#          'base_path': 220,
#          'body': 2258,
#          'change_note': 220,
#          'content_id': 1,
#          'content_type': 1,
#          'created_at': 1,
#          'id': 1,
#          'key': 21,
#          'kind': 636,
#          'name': 12,
#          'note': 3873,
#          'preposition': 9,
#          'public_timestamp': 3873,
#          'published_at': 220,
#          'short_name': 6,
#          'slug': 2260,
#          'text': 1,
#          'title': 2766,
#          'type': 15,
#          'updated_at': 1,
#          'url': 78,
#          'web_url': 3})

# %% [markdown]
# Counter({NoneType: 52752,
#          list: 979755,
#          numpy.bool_: 432006,
#          numpy.int64: 2704,
#          str: 1061581})

# %%
type(content['details'][0])

# %% [markdown]
# #### 5.3 Metrics for text content.

# %%
content['title_len'] = content['title'].map(lambda x: len(x.split()))
content['description_len'] = content['description'].map(lambda x: len(x.split()))
content.head()
# Out:
#                                    base_path  \
# 0                               /vehicle-tax
# 1            /student-finance-register-login
# 2  /government/organisations/companies-house
# 3           /get-information-about-a-company
# 4                         /check-vehicle-tax
#
#                              content_id  \
# 0  fa748fae-3de4-4266-ae85-0797ada3f40c
# 1  e57daef4-5eb5-431c-b0ad-14119ab0355f
# 2  c36bd301-d0c5-4492-86ad-ee7843b8383b
# 3  9ca1a27b-af7b-44d2-b10d-0a6d0e3ff53d
# 4  0889f128-e479-465f-b3e1-a3db6a3879cf
#
#                                          description  \
# 0  renew or tax your vehicle for the first time u...
# 1  your student finance online account - check pa...
# 2
# 3  get company information including registered a...
# 4  check and report if a vehicle has up-to-date v...
#
#                                              details document_type  \
# 0  {'transaction_start_link': 'https://www.vehicl...   transaction
# 1  {'transaction_start_link': 'https://www.studen...   transaction
# 2  {'brand': 'department-for-business-innovation-...  organisation
# 3  {'transaction_start_link': 'https://beta.compa...   transaction
# 4  {'transaction_start_link': 'https://www.vehicl...   transaction
#
#               first_published_at locale primary_publishing_organisation  \
# 0  2016-02-29T09:24:10.000+00:00     en                             NaN
# 1  2016-02-29T09:24:10.000+00:00     en                             NaN
# 2  2016-02-29T09:24:10.000+00:00     en                             NaN
# 3  2016-02-29T09:24:10.000+00:00     en                             NaN
# 4  2016-02-29T09:24:10.000+00:00     en                             NaN
#
#   publishing_app                                             taxons  \
# 0      publisher  [{'title': 'Popular services', 'content_id': '...
# 1      publisher  [{'title': 'Student grants, bursaries and scho...
# 2      whitehall                                                NaN
# 3      publisher  [{'title': 'Business debt and bankruptcy', 'co...
# 4      publisher  [{'title': 'Popular services', 'content_id': '...
#
#                              title  \
# 0                 tax your vehicle
# 1            student finance login
# 2                  companies house
# 3  get information about a company
# 4      check if a vehicle is taxed
#
#                                                 body  title_len  length  \
# 0  tax your car motorcycle or other vehicle using...          3     301
# 1  the student finance england website you’ll be ...          3     162
# 2                                                             2       0
# 3  you can get some details about a company for f...          5     123
# 4  you’ll need the number plate (registration num...          6      63
#
#                                        combined_text  description_len
# 0  tax your vehicle renew or tax your vehicle for...               36
# 1  student finance login your student finance onl...               20
# 2                                 companies house                   0
# 3  get information about a company get company in...               21
# 4  check if a vehicle is taxed check and report i...               15

# %%
print(content['title_len'].describe(),content['description_len'].describe())
print(content['title_len'].sum(),content['description_len'].sum())

# %%
print(content['base_path'].loc[content['title_len']>40].values[0])

# %% [markdown]
# ### Misc. time.

# %% [markdown]
# JSON keys will never be in order, and in general what governs the order of the paragraphs is the rendering app. So, do some discovery work on:
# * Outer tags.
# * Children...

# %%
content.head()
# Out:
#                                    base_path  \
# 0                               /vehicle-tax
# 1            /student-finance-register-login
# 2  /government/organisations/companies-house
# 3           /get-information-about-a-company
# 4                         /check-vehicle-tax
#
#                              content_id  \
# 0  fa748fae-3de4-4266-ae85-0797ada3f40c
# 1  e57daef4-5eb5-431c-b0ad-14119ab0355f
# 2  c36bd301-d0c5-4492-86ad-ee7843b8383b
# 3  9ca1a27b-af7b-44d2-b10d-0a6d0e3ff53d
# 4  0889f128-e479-465f-b3e1-a3db6a3879cf
#
#                                          description  \
# 0  Renew or tax your vehicle for the first time u...
# 1  Your student finance online account - check pa...
# 2                                               None
# 3  Get company information including registered a...
# 4  Check and report if a vehicle has up-to-date v...
#
#                                              details document_type  \
# 0  {'will_continue_on': '', 'department_analytics...   transaction
# 1  {'will_continue_on': 'the Student Finance Engl...   transaction
# 2  {'logo': {'crest': 'single-identity', 'formatt...  organisation
# 3  {'will_continue_on': '', 'department_analytics...   transaction
# 4  {'will_continue_on': '', 'more_information': '...   transaction
#
#               first_published_at locale primary_publishing_organisation  \
# 0  2016-02-29T09:24:10.000+00:00     en                             NaN
# 1  2016-02-29T09:24:10.000+00:00     en                             NaN
# 2  2016-02-29T09:24:10.000+00:00     en                             NaN
# 3  2016-02-29T09:24:10.000+00:00     en                             NaN
# 4  2016-02-29T09:24:10.000+00:00     en                             NaN
#
#   publishing_app                                             taxons  \
# 0      publisher  [{'content_id': '948b6dd4-45b3-45ab-a5c6-5dbce...
# 1      publisher  [{'content_id': '64aa6eec-48b5-481d-9131-9c8b6...
# 2      whitehall                                                NaN
# 3      publisher  [{'content_id': 'a1119685-ffef-4417-a3e4-11601...
# 4      publisher  [{'content_id': '948b6dd4-45b3-45ab-a5c6-5dbce...
#
#                              title
# 0                 Tax your vehicle
# 1            Student finance login
# 2                 Companies House
# 3  Get information about a company
# 4      Check if a vehicle is taxed

# %%
content.columns
# Out:
# Index(['base_path', 'content_id', 'description', 'details', 'document_type',
#        'first_published_at', 'locale', 'primary_publishing_organisation',
#        'publishing_app', 'taxons', 'title'],
#       dtype='object')

# %%
tag_counter = Counter()
for tup in content.itertuples():
    for key in tup[4].keys():
        tag_counter[key]+=1

# %%
print(tag_counter.most_common(10))
for i,key in enumerate(sorted(tag_counter.keys())):
    print(key,"\n")

# %%
filtered = ['government','documents']
filtered = ['brand']
filtered = ['document_noun']
filtered = ['metadata']
filtered = ['organisation']
filtered = ['summary']
filtered = ['tags']
filtered = ['external_related_links']
filtered = ['emphasised_organisations']
filtered = ['final_outcome_detail']
filtered = ['final_outcome_documents']
filtered = ['headers']
filtered = ['licence_identifier']
filtered = ['licence_overview']
filtered = ['licence_short_description']
filtered = ['will_continue_on']

# %%
filtered = ['body','documents','final_outcome_detail','final_outcome_documents',
            'government','headers','introduction','introductory_paragraph',
            'licence_overview','licence_short_description','metadata','more_information','need_to_know',
            'other_ways_to_apply','summary','ways_to_respond','what_you_need_to_know','will_continue_on']

# %%
for tup in content[1:5000].itertuples():
    for key,value in tup[4].items():
        if key in filtered:
            print("KEY:",key,"VALUE:",value,"\n======")
# Out:
# KEY: will_continue_on VALUE: the Student Finance England website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: Universal Jobmatch
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the vehicle enquiry service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Tax Credits service
# ======
# KEY: will_continue_on VALUE: the driving test booking service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the driving test booking service
# ======
# KEY: will_continue_on VALUE: the theory test booking service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: driving licensing online
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: driving licensing online
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Council Tax valuation list
# ======
# KEY: will_continue_on VALUE: driving licensing online
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Safe Driving for Life website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Vehicle Certification Agency (VCA) website
# ======
# KEY: will_continue_on VALUE: the General Register Office ordering service
# ======
# KEY: will_continue_on VALUE: the Companies House service
# ======
# KEY: will_continue_on VALUE: the Universal Credit service
# ======
# KEY: will_continue_on VALUE: the Blue Badge eligibility tool
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: driver licensing online
# ======
# KEY: will_continue_on VALUE: the HMRC website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: DVLA online form ordering
# ======
# KEY: will_continue_on VALUE: the VOA service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Companies House service
# ======
# KEY: will_continue_on VALUE: the Home Office service
# ======
# KEY: will_continue_on VALUE: the Student Finance England website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Home Office website
# ======
# KEY: will_continue_on VALUE: the NHS Choices service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Companies House service
# ======
# KEY: will_continue_on VALUE: Government Gateway sign-in
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: driving licensing online
# ======
# KEY: will_continue_on VALUE: the vehicle recalls service
# ======
# KEY: will_continue_on VALUE: the price paid data service
# ======
# KEY: will_continue_on VALUE: the theory test booking service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the pay a court fine service
# ======
# KEY: will_continue_on VALUE: Universal Jobmatch
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the TV Licensing website
# ======
# KEY: will_continue_on VALUE: the HMRC website
# ======
# KEY: will_continue_on VALUE: the Pension Credit calculator
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the DVSA practical test business service
# ======
# KEY: will_continue_on VALUE: the Money Claim Online website
# ======
# KEY: will_continue_on VALUE: the HM Revenue & Customs website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Disclosure Scotland website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: driving licensing online
# ======
# KEY: will_continue_on VALUE: the driving test booking service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: driving licensing online
# ======
# KEY: will_continue_on VALUE: the DVLA Personalised Registrations service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Charity Commission service
# ======
# KEY: will_continue_on VALUE: the Ofsted website
# ======
# KEY: will_continue_on VALUE: the HMRC website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Department for Transport website
# ======
# KEY: will_continue_on VALUE: the Vehicle Certification Agency (VCA) website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the find driving instructors service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Carer's Allowance service
# ======
# KEY: will_continue_on VALUE: the Trading Standards Institute website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Start Up Loans website
# ======
# KEY: will_continue_on VALUE: the Home Office service
# ======
# KEY: will_continue_on VALUE: the theory test booking service
# ======
# KEY: will_continue_on VALUE: the Police UK website and find your local police force
# ======
# KEY: will_continue_on VALUE: the Home Office website
# ======
# KEY: will_continue_on VALUE: the theory test booking service
# ======
# KEY: will_continue_on VALUE: the HMRC fraud hotline report form
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Planning Inspectorate website
# ======
# KEY: will_continue_on VALUE: the Government Property Finder service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Children's Centres finder
# ======
# KEY: will_continue_on VALUE: the Pensions Service website
# ======
# KEY: will_continue_on VALUE: the Criminal Injuries Compensation Authority (CICA) website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Home Office website
# ======
# KEY: will_continue_on VALUE: the driving test booking service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the HGV levy service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the biometric residence permit service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the PRS for Music website
# ======
# KEY: will_continue_on VALUE: the car tax enforcement website
# ======
# KEY: will_continue_on VALUE: the InnovateUK innovation funding finder
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the BCMS website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the court and tribunal finder
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the theory test booking service
# ======
# KEY: will_continue_on VALUE: the HMRC website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the petitions service
# ======
# KEY: will_continue_on VALUE: the UK house price index service
# ======
# KEY: will_continue_on VALUE: the Graduate Talent Pool
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Intellectual Property Office service
# ======
# KEY: will_continue_on VALUE: the Ofqual service
# ======
# KEY: will_continue_on VALUE: the Home Office website
# ======
# KEY: will_continue_on VALUE: the Online Disclosures service
# ======
# KEY: will_continue_on VALUE: the commercial vehicle compliance service
# ======
# KEY: will_continue_on VALUE: the Joint Approvals Unit for Periodic Training (JAUPT) website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the MHRA website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the HMRC website
# ======
# KEY: will_continue_on VALUE: the Ofqual service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the "What's In Your Backyard" service
# ======
# KEY: will_continue_on VALUE: the Possession Claim Online website
# ======
# KEY: will_continue_on VALUE: the Intellectual Property Office service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the driving instructor service
# ======
# KEY: will_continue_on VALUE: the Transport for London (TfL) website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Information Commissioner's Office (ICO) service
# ======
# KEY: will_continue_on VALUE: the National Driver Offender Retraining Scheme website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the technical application submission (TAS) service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Insolvency Service website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Valuation Office Agency's service
# ======
# KEY: will_continue_on VALUE: HMRC online services
# ======
# KEY: will_continue_on VALUE: the Intellectual Property Office service
# ======
# KEY: will_continue_on VALUE: the theory test booking service
# ======
# KEY: will_continue_on VALUE: the Home Office website
# ======
# KEY: will_continue_on VALUE: the driving instructor service
# ======
# KEY: will_continue_on VALUE: the Alcohol Wholesaler Registration Scheme (AWRS)
# ======
# KEY: will_continue_on VALUE: the MI5 website
# ======
# KEY: will_continue_on VALUE: the Home Office website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Security Industry Authority (SIA) website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Inspiring Governance website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the HMRC website
# ======
# KEY: will_continue_on VALUE: the Veterinary Medicines Directorate service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the HMRC website
# ======
# KEY: will_continue_on VALUE: the HMRC service
# ======
# KEY: will_continue_on VALUE: the Yellow Card Scheme website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Department for Transport website
# ======
# KEY: will_continue_on VALUE: the Justice website
# ======
# KEY: will_continue_on VALUE: the Online Disclosures service
# ======
# KEY: will_continue_on VALUE: the Phonographic Performance Limited website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Digital Marketplace
# ======
# KEY: will_continue_on VALUE: the General Register Office service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: First-tier Tribunal (Tax Chamber) decisions website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:  the Vehicle Certification Agency (VCA) website
# ======
# KEY: will_continue_on VALUE: the Immigration and asylum appeal decisions website
# ======
# KEY: will_continue_on VALUE: the theory test booking service
# ======
# KEY: will_continue_on VALUE: the Veterans UK service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: IPO online services
# ======
# KEY: will_continue_on VALUE: the theory test booking service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the MHRA website
# ======
# KEY: will_continue_on VALUE: the technical application submission (TAS) service
# ======
# KEY: will_continue_on VALUE: the report a lost or stolen badge tool
# ======
# KEY: will_continue_on VALUE: the public appointments website
# ======
# KEY: will_continue_on VALUE: the Intellectual Property Office service
# ======
# KEY: will_continue_on VALUE: drwyddedu gyrru arlein
# ======
# KEY: will_continue_on VALUE: the Department for Transport website
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the Department for Transport service
# ======
# KEY: will_continue_on VALUE:
# ======
# KEY: will_continue_on VALUE: the DVSA website
# ======
# KEY: will_continue_on VALUE: the online report service
# ======

# %% [markdown]
# [('body', 185083), ('change_history', 183389), ('first_public_at', 181142), ('political', 179039), ('government', 179039), ('emphasised_organisations', 172831), ('tags', 168074), ('documents', 95670), ('image', 75520), ('national_applicability', 17644)]
#
# 0 document_noun
# 1 emphasised_organisations
# 2 format_sub_type
# 3 email
# 4 external_related_links
# 5 service_tiers
# 6 final_outcome_detail
# 7 organisation
# 8 brand
# 9 need_to_know
# 10 licence_short_description
# 11 show_summaries
# 12 political
# 13 held_on_another_website_url
# 14 metadata
# 15 visible_to_departmental_editors
# 16 will_continue_on
# 17 public_feedback_detail
# 18 summary
# 19 more_information
# 20 introductory_paragraph
# 21 what_you_need_to_know
# 22 ways_to_respond
# 23 internal_name
# 24 government
# 25 delivered_on
# 26 default_documents_per_page
# 27 cancellation_reason
# 28 licence_overview
# 29 headers
# 30 continuation_link
# 31 change_notes
# 32 body
# 33 human_readable_finder_format
# 34 end_date
# 35 nation_applicability
# 36 collection_groups
# 37 facets
# 38 lgil_code
# 39 logo
# 40 introduction
# 41 state
# 42 licence_identifier
# 43 temporary_update_type
# 44 organisations
# 45 notes_for_editors
# 46 parts
# 47 opening_date
# 48 latest_change_note
# 49 start_button_text
# 50 tags
# 51 change_note
# 52 format_display_type
# 53 public_feedback_publication_date
# 54 child_section_groups
# 55 nodes
# 56 speech_type_explanation
# 57 closing_date
# 58 department_analytics_profile
# 59 related_mainstream_content
# 60 change_history
# 61 public_feedback_documents
# 62 filter
# 63 first_public_at
# 64 cancelled_at
# 65 documents
# 66 place_type
# 67 final_outcome_documents
# 68 image
# 69 max_cache_time
# 70 signup_link
# 71 transaction_start_link
# 72 other_ways_to_apply
# 73 display_date
# 74 previous_display_date
# 75 lgsl_code
# 76 start_date
# 77 national_applicability
# 78 attachments

# %%
print(tag_counter['introductory_paragraph'])
# Out:
# 334
