# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.externals import joblib
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import AdaBoostClassifier
from sklearn.cross_validation import cross_val_score
from sklearn.feature_selection import SelectPercentile, f_classif
from sklearn.svm import LinearSVC
# Out:
# /Users/felisialoukou/.pyenv/versions/3.4.6/lib/python3.4/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Becuase the file is large it uses the low_memory option 
# to read the file in chunks. The result of this is that it
# it infers different column types in the different chunks,
# solve this either by reading the file in a oner with low_memory=False,
# or be explicit about the column types by setting them with dtype = {'column':type}

labelled_level2 = pd.read_csv(
    '../../../../data/labelled_level2.csv',
    low_memory=False
)

# %%
labelled_level2.shape
# Out:
# (173560, 21)

# %%
# Collapse down World

labelled_level2.loc[labelled_level2['level1taxon'] == 'World', 'level2taxon'] = 'world_level1'

# %%
# There are are 210 unique taxons remaining in level2taxon

labelled_level2['level2taxon'].nunique()
# Out:
# 210

# %%
# Drop cases where there are multiple taxons applied to a content item.
# This is the simplest solution to the multiple class problem

print('Before:', labelled_level2.shape)
labelled_level2.drop_duplicates(subset=['content_id'], inplace=True, keep='first')
print('After: ', labelled_level2.shape)
# Out:
# Before: (173560, 21)
# After:  (114048, 21)

# %%
# ----- PIPELINE THE DATA-PREP INSTEAD OF DOING IN MODEL DEFINITION -----
comment_pipeline = Pipeline([
                   ('vect', CountVectorizer()),
                   ('tfidf', TfidfTransformer(sublinear_tf=True, use_idf=True)),
                   ('anova', SelectPercentile())
])

text = comment_pipeline.fit_transform(labelled_level2['combined_text'],labelled_level2['level2taxon'])
# Out:
# /Users/felisialoukou/.pyenv/versions/3.4.6/lib/python3.4/site-packages/sklearn/feature_selection/univariate_selection.py:114: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw

# %%
# ----- PREPARE TRAIN/TEST DATA -----
X_train, X_test, y_train, y_test = train_test_split(
    text, labelled_level2['level2taxon'], test_size = 0.2, random_state=1337)

# %%
# ----- MACHINE LEARNING MODEL -----
svc_clf = Pipeline([
                   ('svc', LinearSVC(C=10.0, dual=False, loss="squared_hinge", penalty="l2",
                                     multi_class='ovr', tol=0.01))
                   ])

# %%
svc_clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('svc', LinearSVC(C=10.0, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.01,
#      verbose=0))])

# %%
""" Predict the test dataset using LinearSVC"""
predicted_svc = svc_clf.predict(X_test)
print('SVC correct prediction: {:4.2f}'.format(np.mean(predicted_svc == y_test)))
# Out:
# SVC correct prediction: 0.81

# %%
rep = classification_report(y_test, predicted_svc)
print(rep)
to_table(rep)
# Out:
#                                                                         precision    recall  f1-score   support
#
#                                          Administrative justice reform       0.00      0.00      0.00         3
#                                      Adoption, fostering and surrogacy       0.83      0.83      0.83         6
#                                                  Armed Forces Covenant       0.33      0.25      0.29         4
#                            Armed forces and Ministry of Defence reform       0.00      0.00      0.00         2
#                          Armed forces support for activities in the UK       0.00      0.00      0.00         1
#                                                       Arts and culture       0.76      0.80      0.78       270
#                                         Assessing environmental impact       0.50      1.00      0.67         1
#                                                                 Asylum       0.50      0.75      0.60         4
#                      Attorney General guidance to the legal profession       0.75      0.75      0.75         4
#                                                      Sentencing reform       0.00      0.00      0.00         1
#                                                            Social care       0.61      0.45      0.52        78
#         Special educational needs and disability (SEND) and high needs       0.84      0.90      0.87        30
#                                                     Sports and leisure       0.79      0.87      0.83       142
#                                          Starting and attending school       0.00      0.00      0.00         4
# Support services for military and defence personnel and their families       0.71      0.83      0.77         6
#                       Support services for veterans and their families       0.91      0.83      0.87        12
#                                                Sustainable development       0.00      0.00      0.00         3
#                                                            Tax credits       1.00      0.60      0.75         5
#                                              Tax evasion and avoidance       0.84      0.79      0.81        33
#                                                Teaching and leadership       0.91      0.93      0.92       207
#                                                                Tourism       0.50      0.50      0.50         6
#                                                   Trade and investment       0.83      0.84      0.84       608
#                                   Transport accessibility and mobility       1.00      0.75      0.86         4
#                                   Transport corporate and transparency       0.61      0.65      0.63        51
#                                      Transport modelling and appraisal       1.00      0.92      0.96        12
#                                                     Transport planning       0.00      0.00      0.00         2
#                                      Transport research and evaluation       0.00      0.00      0.00         1
#                                                   Transport statistics       0.95      0.94      0.94       147
#                                                          Travel abroad       0.00      0.00      0.00         1
#                                                      UK border control       1.00      0.50      0.67         2
#                                                             UK economy       0.77      0.78      0.78       784
#                                                   UK nuclear deterrent       0.33      0.33      0.33         3
#             UK prosperity and security: Asia, Latin America and Africa       1.00      0.50      0.67         2
#                                                       Universal Credit       0.00      0.00      0.00         1
#                                                       Victims of crime       0.60      0.60      0.60         5
#                                       Violence against women and girls       0.84      0.84      0.84        37
#                                                                  Visas       0.80      0.62      0.70        26
#                                                                 Voting       1.00      0.50      0.67         2
#                                                                  Wales       0.88      0.89      0.88       262
#                                                    Waste and recycling       0.81      0.82      0.82       107
#                                                         Water industry       0.63      0.71      0.67        48
#                                            Wildlife and animal welfare       0.71      0.42      0.53        12
#                                             Working, jobs and pensions       0.75      0.60      0.67        10
#                                               Young people and the law       1.00      0.25      0.40         4
#                                                Your rights and the law       0.00      0.00      0.00         3
#                                     Youth employment and social issues       0.00      0.00      0.00         2
#                                                           world_level1       0.92      0.93      0.92       192
#
#                                                            avg / total       0.81      0.81      0.81     15181
# /Users/felisialoukou/.pyenv/versions/3.4.6/lib/python3.4/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/felisialoukou/.pyenv/versions/3.4.6/lib/python3.4/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [['', 'precision', 'recall', 'f1-score', 'support'],
#  ['Administrative', 'justice', 'reform', '0.00', '0.00', '0.00', '3'],
#  ['Adoption,', 'fostering', 'and', 'surrogacy', '0.83', '0.83', '0.83', '6'],
#  ['Armed', 'Forces', 'Covenant', '0.33', '0.25', '0.29', '4'],
#  ['Armed',
#   'forces',
#   'and',
#   'Ministry',
#   'of',
#   'Defence',
#   'reform',
#   '0.00',
#   '0.00',
#   '0.00',
#   '2'],
#  ['Armed',
#   'forces',
#   'support',
#   'for',
#   'activities',
#   'in',
#   'the',
#   'UK',
#   '0.00',
#   '0.00',
#   '0.00',
#   '1'],
#  ['Arts', 'and', 'culture', '0.76', '0.80', '0.78', '270'],
#  ['Assessing', 'environmental', 'impact', '0.50', '1.00', '0.67', '1'],
#  ['Asylum', '0.50', '0.75', '0.60', '4'],
#  ['Attorney',
#   'General',
#   'guidance',
#   'to',
#   'the',
#   'legal',
#   'profession',
#   '0.75',
#   '0.75',
#   '0.75',
#   '4'],
#  ['Aviation', '0.76', '0.68', '0.72', '19'],
#  ['Benefits', 'entitlement', '0.00', '0.00', '0.00', '7'],
#  ['Biodiversity', 'and', 'ecosystems', '0.60', '0.53', '0.56', '51'],
#  ['Brexit', '0.84', '0.73', '0.78', '37'],
#  ['Brexit', 'and', 'the', 'EU', '0.00', '0.00', '0.00', '2'],
#  ['British', 'citizenship', '1.00', '0.50', '0.67', '2'],
#  ['British', 'nationals', 'overseas', '1.00', '0.14', '0.25', '7'],
#  ['Business', 'and', 'enterprise', '0.81', '0.81', '0.81', '1226'],
#  ['Business', 'and', 'the', 'environment', '0.58', '0.59', '0.59', '86'],
#  ['Business', 'tax', '0.77', '0.79', '0.78', '241'],
#  ['Carers', 'and', 'disability', 'benefits', '0.00', '0.00', '0.00', '1'],
#  ['Certificates,',
#   'register',
#   'offices,',
#   'changes',
#   'of',
#   'name',
#   'or',
#   'gender',
#   '1.00',
#   '0.50',
#   '0.67',
#   '2'],
#  ['Charities,', 'volunteering', 'and', 'honours', '0.00', '0.00', '0.00', '2'],
#  ['Child', 'Benefit', '0.50', '0.67', '0.57', '6'],
#  ['Child', 'maintenance', 'reform', '0.75', '0.50', '0.60', '6'],
#  ['Childcare', 'and', 'early', 'years', '0.90', '0.86', '0.88', '21'],
#  ["Children's", 'health', 'and', 'welfare', '0.00', '0.00', '0.00', '0'],
#  ['Civil', 'service', 'reform', '0.80', '0.80', '0.80', '5'],
#  ['Climate', 'change', 'and', 'energy', '0.85', '0.85', '0.85', '690'],
#  ['Commercial', 'fishing', 'and', 'fisheries', '0.74', '0.78', '0.76', '18'],
#  ['Community', 'and', 'society', '0.73', '0.70', '0.71', '415'],
#  ['Consumer', 'rights', 'and', 'issues', '0.69', '0.66', '0.67', '88'],
#  ['Content', 'and', 'publishing', '0.00', '0.00', '0.00', '2'],
#  ['Court',
#   'claims,',
#   'debt',
#   'and',
#   'bankruptcy',
#   '0.00',
#   '0.00',
#   '0.00',
#   '4'],
#  ['Courts,', 'sentencing', 'and', 'tribunals', '0.80', '0.44', '0.57', '9'],
#  ['Crime', 'prevention', '0.50', '0.37', '0.42', '52'],
#  ['Criminal', 'justice', 'reform', '0.40', '0.50', '0.44', '8'],
#  ['Dealing', 'with', 'HMRC', '0.76', '0.76', '0.76', '136'],
#  ['Death', 'and', 'bereavement', '0.50', '1.00', '0.67', '1'],
#  ['Deficit', 'reduction', '0.00', '0.00', '0.00', '0'],
#  ['Disabled', 'people', '0.00', '0.00', '0.00', '1'],
#  ['Driving', 'and', 'road', 'transport', '0.82', '0.83', '0.82', '179'],
#  ['Education', 'of', 'disadvantaged', 'children', '0.29', '0.22', '0.25', '9'],
#  ['Emergency',
#   'preparation,',
#   'response',
#   'and',
#   'recovery',
#   '0.61',
#   '0.35',
#   '0.45',
#   '54'],
#  ['Employing', 'people', '0.00', '0.00', '0.00', '3'],
#  ['End', 'of', 'life', 'care', '0.00', '0.00', '0.00', '1'],
#  ['Environmental', 'permits', '0.00', '0.00', '0.00', '0'],
#  ['Environmental', 'quality', '0.90', '0.58', '0.71', '62'],
#  ['Equality,', 'rights', 'and', 'citizenship', '0.70', '0.72', '0.71', '276'],
#  ['European', 'funds', '0.00', '0.00', '0.00', '2'],
#  ['Family', 'justice', 'system', '0.90', '1.00', '0.95', '9'],
#  ['Financial', 'services', '0.67', '0.70', '0.68', '90'],
#  ['Flooding', 'and', 'coastal', 'change', '0.93', '0.95', '0.94', '175'],
#  ['Food', 'and', 'farming', '0.90', '0.88', '0.89', '359'],
#  ['Forced', 'marriage', '0.00', '0.00', '0.00', '0'],
#  ['Foreign', 'affairs', '0.83', '0.45', '0.59', '11'],
#  ['Freight', 'and', 'cargo', '0.58', '0.58', '0.58', '12'],
#  ['Funding',
#   'and',
#   'finance',
#   'for',
#   'students',
#   '0.67',
#   '0.71',
#   '0.69',
#   '17'],
#  ['Further',
#   'and',
#   'higher',
#   'education,',
#   'skills',
#   'and',
#   'vocational',
#   'training',
#   '0.84',
#   '0.88',
#   '0.86',
#   '273'],
#  ['Government',
#   'efficiency,',
#   'transparency',
#   'and',
#   'accountability',
#   '0.83',
#   '0.85',
#   '0.84',
#   '1498'],
#  ['Government', 'graduate', 'schemes', '0.00', '0.00', '0.00', '2'],
#  ['Government', 'spending', '0.49', '0.42', '0.45', '84'],
#  ['Health', 'protection', '0.00', '0.00', '0.00', '1'],
#  ['Heating', 'and', 'housing', 'benefits', '0.00', '0.00', '0.00', '2'],
#  ['Housing', '0.79', '0.81', '0.80', '359'],
#  ['Housing', 'planning', 'and', 'building', '0.84', '0.86', '0.85', '364'],
#  ['Immigration', 'rules', 'and', 'enforcement', '0.75', '0.55', '0.63', '11'],
#  ['Industrial', 'strategy', '0.00', '0.00', '0.00', '0'],
#  ['Inspections',
#   'and',
#   'performance',
#   'of',
#   'education',
#   'providers',
#   '0.81',
#   '0.85',
#   '0.83',
#   '155'],
#  ['International', 'aid', 'and', 'development', '0.84', '0.91', '0.87', '591'],
#  ["Jobseeker's",
#   'Allowance',
#   'and',
#   'low',
#   'income',
#   'benefits',
#   '0.00',
#   '0.00',
#   '0.00',
#   '2'],
#  ['Justice', 'system', 'transparency', '0.62', '0.50', '0.55', '32'],
#  ['Knife,', 'gun', 'and', 'gang', 'crime', '0.71', '0.71', '0.71', '14'],
#  ['Labour', 'market', 'reform', '0.75', '0.79', '0.77', '68'],
#  ['Land', 'management', '1.00', '1.00', '1.00', '1'],
#  ['Land', 'registration', '0.00', '0.00', '0.00', '0'],
#  ['Lasting',
#   'power',
#   'of',
#   'attorney,',
#   'being',
#   'in',
#   'care',
#   'and',
#   'your',
#   'financial',
#   'affairs',
#   '0.67',
#   '0.67',
#   '0.67',
#   '3'],
#  ['Legal', 'aid', '0.78', '0.78', '0.78', '23'],
#  ['Legal', 'aid', 'reform', '1.00', '0.62', '0.77', '8'],
#  ['Living',
#   'in',
#   'the',
#   'UK,',
#   'government',
#   'and',
#   'democracy',
#   '0.00',
#   '0.00',
#   '0.00',
#   '2'],
#  ['Local', 'councils', 'and', 'services', '0.50', '0.33', '0.40', '3'],
#  ['Local', 'government', '0.80', '0.79', '0.80', '189'],
#  ['Local', 'transport', '0.60', '0.60', '0.60', '5'],
#  ['Localism', '1.00', '0.33', '0.50', '3'],
#  ['Marine', '0.81', '0.85', '0.83', '81'],
#  ['Maritime', '0.90', '0.88', '0.89', '128'],
#  ['Marriage,',
#   'civil',
#   'partnership',
#   'and',
#   'divorce',
#   '1.00',
#   '0.33',
#   '0.50',
#   '3'],
#  ['Media', 'and', 'communications', '0.72', '0.73', '0.73', '180'],
#  ['Medicines,',
#   'medical',
#   'devices',
#   'and',
#   'blood',
#   'regulation',
#   'and',
#   'safety',
#   '0.00',
#   '0.00',
#   '0.00',
#   '2'],
#  ['Military', 'awards', 'and', 'commemorations', '1.00', '0.50', '0.67', '2'],
#  ['Military',
#   'equipment,',
#   'logistics',
#   'and',
#   'technology',
#   '0.00',
#   '0.00',
#   '0.00',
#   '2'],
#  ['Military',
#   'recruitment,',
#   'training',
#   'and',
#   'operations',
#   '0.50',
#   '0.40',
#   '0.44',
#   '5'],
#  ['Ministry', 'of', 'Defence', 'estate', '0.00', '0.00', '0.00', '2'],
#  ['Money', 'laundering', 'regulations', '1.00', '1.00', '1.00', '6'],
#  ['National', 'Health', 'Service', '0.88', '0.88', '0.88', '551'],
#  ['National', 'events', 'and', 'ceremonies', '0.83', '0.62', '0.71', '8'],
#  ['National', 'security', '0.67', '0.68', '0.67', '111'],
#  ['Northern', 'Ireland', '0.89', '0.91', '0.90', '169'],
#  ['Nuclear', 'disarmament', '0.00', '0.00', '0.00', '1'],
#  ['Oil', 'and', 'gas', '0.86', '0.86', '0.86', '7'],
#  ['Passports', '0.50', '0.50', '0.50', '2'],
#  ['Passports',
#   'and',
#   'travel',
#   'documents',
#   'for',
#   'foreign',
#   'nationals',
#   '0.50',
#   '0.50',
#   '0.50',
#   '4'],
#  ['Pensions', 'and', 'ageing', 'society', '0.78', '0.83', '0.81', '120'],
#  ['Permanent', 'stay', 'in', 'the', 'UK', '0.50', '0.50', '0.50', '2'],
#  ['Personal', 'tax', '0.76', '0.77', '0.76', '126'],
#  ['Policing', '0.81', '0.75', '0.78', '121'],
#  ['Postal', 'service', 'reform', '0.50', '0.33', '0.40', '3'],
#  ['Prisons', 'and', 'probation', '1.00', '0.25', '0.40', '4'],
#  ['Public', 'health', '0.87', '0.92', '0.89', '768'],
#  ['Pupil',
#   'wellbeing,',
#   'behaviour',
#   'and',
#   'attendance',
#   '0.88',
#   '0.72',
#   '0.79',
#   '50'],
#  ['Rail', '0.86', '0.74', '0.79', '84'],
#  ['Regulation', 'reform', '0.00', '0.00', '0.00', '2'],
#  ['Reoffending', 'and', 'rehabilitation', '0.68', '0.72', '0.70', '18'],
#  ['Reporting',
#   'crimes',
#   'and',
#   'getting',
#   'compensation',
#   '0.00',
#   '0.00',
#   '0.00',
#   '4'],
#  ['Road', 'infrastructure', '0.52', '0.43', '0.47', '28'],
#  ['Running', 'and', 'managing', 'a', 'school', '0.84', '0.82', '0.83', '179'],
#  ['Rural', 'and', 'countryside', '0.86', '0.85', '0.85', '205'],
#  ['Safeguarding',
#   'and',
#   'social',
#   'care',
#   'for',
#   'children',
#   '0.68',
#   '0.77',
#   '0.72',
#   '44'],
#  ['School',
#   'and',
#   'academy',
#   'financial',
#   'management',
#   'and',
#   'assurance',
#   '0.89',
#   '0.76',
#   '0.82',
#   '21'],
#  ['School', 'and', 'academy', 'funding', '0.78', '0.75', '0.77', '76'],
#  ['School', 'curriculum', '0.90', '0.91', '0.91', '291'],
#  ['Science', 'and', 'innovation', '0.78', '0.80', '0.79', '388'],
#  ['Scotland', '0.87', '0.87', '0.87', '135'],
#  ['Self-employment', '0.00', '0.00', '0.00', '1'],
#  ['Sentencing', 'reform', '0.00', '0.00', '0.00', '1'],
#  ['Social', 'care', '0.61', '0.45', '0.52', '78'],
#  ['Special',
#   'educational',
#   'needs',
#   'and',
#   'disability',
#   '(SEND)',
#   'and',
#   'high',
#   'needs',
#   '0.84',
#   '0.90',
#   '0.87',
#   '30'],
#  ['Sports', 'and', 'leisure', '0.79', '0.87', '0.83', '142'],
#  ['Starting', 'and', 'attending', 'school', '0.00', '0.00', '0.00', '4'],
#  ['Support',
#   'services',
#   'for',
#   'military',
#   'and',
#   'defence',
#   'personnel',
#   'and',
#   'their',
#   'families',
#   '0.71',
#   '0.83',
#   '0.77',
#   '6'],
#  ['Support',
#   'services',
#   'for',
#   'veterans',
#   'and',
#   'their',
#   'families',
#   '0.91',
#   '0.83',
#   '0.87',
#   '12'],
#  ['Sustainable', 'development', '0.00', '0.00', '0.00', '3'],
#  ['Tax', 'credits', '1.00', '0.60', '0.75', '5'],
#  ['Tax', 'evasion', 'and', 'avoidance', '0.84', '0.79', '0.81', '33'],
#  ['Teaching', 'and', 'leadership', '0.91', '0.93', '0.92', '207'],
#  ['Tourism', '0.50', '0.50', '0.50', '6'],
#  ['Trade', 'and', 'investment', '0.83', '0.84', '0.84', '608'],
#  ['Transport',
#   'accessibility',
#   'and',
#   'mobility',
#   '1.00',
#   '0.75',
#   '0.86',
#   '4'],
#  ['Transport',
#   'corporate',
#   'and',
#   'transparency',
#   '0.61',
#   '0.65',
#   '0.63',
#   '51'],
#  ['Transport', 'modelling', 'and', 'appraisal', '1.00', '0.92', '0.96', '12'],
#  ['Transport', 'planning', '0.00', '0.00', '0.00', '2'],
#  ['Transport', 'research', 'and', 'evaluation', '0.00', '0.00', '0.00', '1'],
#  ['Transport', 'statistics', '0.95', '0.94', '0.94', '147'],
#  ['Travel', 'abroad', '0.00', '0.00', '0.00', '1'],
#  ['UK', 'border', 'control', '1.00', '0.50', '0.67', '2'],
#  ['UK', 'economy', '0.77', '0.78', '0.78', '784'],
#  ['UK', 'nuclear', 'deterrent', '0.33', '0.33', '0.33', '3'],
#  ['UK',
#   'prosperity',
#   'and',
#   'security:',
#   'Asia,',
#   'Latin',
#   'America',
#   'and',
#   'Africa',
#   '1.00',
#   '0.50',
#   '0.67',
#   '2'],
#  ['Universal', 'Credit', '0.00', '0.00', '0.00', '1'],
#  ['Victims', 'of', 'crime', '0.60', '0.60', '0.60', '5'],
#  ['Violence',
#   'against',
#   'women',
#   'and',
#   'girls',
#   '0.84',
#   '0.84',
#   '0.84',
#   '37'],
#  ['Visas', '0.80', '0.62', '0.70', '26'],
#  ['Voting', '1.00', '0.50', '0.67', '2'],
#  ['Wales', '0.88', '0.89', '0.88', '262'],
#  ['Waste', 'and', 'recycling', '0.81', '0.82', '0.82', '107'],
#  ['Water', 'industry', '0.63', '0.71', '0.67', '48'],
#  ['Wildlife', 'and', 'animal', 'welfare', '0.71', '0.42', '0.53', '12'],
#  ['Working,', 'jobs', 'and', 'pensions', '0.75', '0.60', '0.67', '10'],
#  ['Young', 'people', 'and', 'the', 'law', '1.00', '0.25', '0.40', '4'],
#  ['Your', 'rights', 'and', 'the', 'law', '0.00', '0.00', '0.00', '3'],
#  ['Youth',
#   'employment',
#   'and',
#   'social',
#   'issues',
#   '0.00',
#   '0.00',
#   '0.00',
#   '2'],
#  ['world_level1', '0.92', '0.93', '0.92', '192'],
#  ['avg / total', '0.81', '0.81', '0.81', '15181']]

# %%
def to_table(report):
    report = report.splitlines()
    res = []
    res.append(['']+report[0].split())
    for row in report[2:-2]:
       res.append(row.split())
    lr = report[-1].split()
    res.append([' '.join(lr[:3])]+lr[3:])
    return res

# %% [markdown]
# ## Metadata Classifier

# %%
labelled_level2.columns

# %%
metadata = labelled_level2.filter(['document_type', 'primary_publishing_organisation', 
                                   'publishing_app', 'document_type_gp', 'locale'], axis=1)

# %%
meta = meta_pipeline.fit_transform(metadata2,labelled_level2['level2taxon'])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    meta, labelled_level2['level2taxon'], test_size = 0.2, random_state=1337)

# %%
ada_clf = AdaBoostClassifier()

ada_clf.fit(X_train, y_train)

# %%
predicted_ada = ada_clf.predict(X_test)

# %%
print('Adaboost correct prediction: {:4.2f}'.format(np.mean(predicted_ada == y_test)))

# %%
print(classification_report(y_test, predicted_ada))

# %%
from sklearn.ensemble import RandomForestClassifier

rfo_clf = RandomForestClassifier()
rfo_clf.fit(X_train, y_train)

# %%
predicted_rfo = rfo_clf.predict(X_test)
print('Adaboost correct prediction: {:4.2f}'.format(np.mean(predicted_rfo == y_test)))

# %%
print(classification_report(y_test, predicted_ada))

# %%
from sklearn.linear_model import LogisticRegression

# %%
predicted_rfo = rfo_clf.predict_proba(X_test)
predicted_ada = ada_clf.predict_proba(X_test)

# %%
blended = pd.DataFrame(np.c_[
    predicted_rfo, predicted_ada
])

# %%
blended_model = LogisticRegression(random_state=1337)
blended_model.fit(blended, y_test)

# %%
blended_pred = blended_model.predict(blended)
class_report = classification_report(y_test, blended_pred)
print(class_report)
blended_model.get_params()

# %%
# Double check this with CV

scores = cross_val_score(blended_model, X_test, y_test,
                        scoring='accuracy',cv=10)

print(round(scores.mean(),3))
print(round(scores.std(),3))
#72
